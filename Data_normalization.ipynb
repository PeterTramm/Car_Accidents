# %% [markdown]
# # Normilization of cleanned data tables

# %%
# Load libraries 

import pandas as pd 
import os

# %%
path = "./Resources/Cleanned/accident_df.csv"

accident_df = pd.read_csv(path)

# %%
accident_df.head(5)
# Out:
#     ACCIDENT_NO ACCIDENT_DATE ACCIDENT_TIME  ACCIDENT_TYPE  \
# 0  T20120000060    2012-01-01      19:40:00              6
# 1  T20120000028    2012-01-01      04:00:00              4
# 2  T20120000021    2012-01-01      07:30:00              4
# 3  T20120000050    2012-01-01      15:00:00              4
# 4  T20120000056    2012-01-01      16:15:00              4
#
#                   ACCIDENT_TYPE_DESC DAY_WEEK_DESC  DCA_CODE  \
# 0  Vehicle overturned (no collision)        Sunday       184
# 1      Collision with a fixed object        Sunday       183
# 2      Collision with a fixed object        Sunday       171
# 3      Collision with a fixed object        Sunday       171
# 4      Collision with a fixed object        Sunday       183
#
#                                           DCA_DESC  LIGHT_CONDITION  NODE_ID  \
# 0          OUT OF CONTROL ON CARRIAGEWAY (ON BEND)                1   248602
# 1         OFF LEFT BEND INTO OBJECT/PARKED VEHICLE                5   248598
# 2  LEFT OFF CARRIAGEWAY INTO OBJECT/PARKED VEHICLE                1   248597
# 3  LEFT OFF CARRIAGEWAY INTO OBJECT/PARKED VEHICLE                1   248600
# 4         OFF LEFT BEND INTO OBJECT/PARKED VEHICLE                1   249133
#
#    ...  NO_PERSONS_INJ_2  NO_PERSONS_INJ_3  NO_PERSONS_NOT_INJ  NO_PERSONS  \
# 0  ...                 1                 0                   0           1
# 1  ...                 1                 0                   0           1
# 2  ...                 0                 2                   1           3
# 3  ...                 0                 1                   0           1
# 4  ...                 2                 0                   0           2
#
#    POLICE_ATTEND  ROAD_GEOMETRY   ROAD_GEOMETRY_DESC  SEVERITY SPEED_ZONE  \
# 0              1              2       T intersection         2         60
# 1              1              2       T intersection         2        100
# 2              1              5  Not at intersection         3         50
# 3              1              5  Not at intersection         3        999
# 4              1              2       T intersection         2        100
#
#           RMA
# 0  Local Road
# 1  Local Road
# 2  Local Road
# 3  Local Road
# 4  Local Road
#
# [5 rows x 22 columns]

# %%
accident_df.columns
# Out:
# Index(['ACCIDENT_NO', 'ACCIDENT_DATE', 'ACCIDENT_TIME', 'ACCIDENT_TYPE',
#        'ACCIDENT_TYPE_DESC', 'DAY_WEEK_DESC', 'DCA_CODE', 'DCA_DESC',
#        'LIGHT_CONDITION', 'NODE_ID', 'NO_OF_VEHICLES', 'NO_PERSONS_KILLED',
#        'NO_PERSONS_INJ_2', 'NO_PERSONS_INJ_3', 'NO_PERSONS_NOT_INJ',
#        'NO_PERSONS', 'POLICE_ATTEND', 'ROAD_GEOMETRY', 'ROAD_GEOMETRY_DESC',
#        'SEVERITY', 'SPEED_ZONE', 'RMA'],
#       dtype='object')

# %% [markdown]
# # -----------------------------------------------------------------------------------------

# %% [markdown]
# # Base Table
# 'ACCIDENT_NO', 'ACCIDENT_DATE', 'ACCIDENT_TIME', 'ACCIDENT_TYPE','ACCIDENT_TYPE_DESC', 'DAY_WEEK_DESC', 'DCA_CODE', 'DCA_DESC','LIGHT_CONDITION', 'NODE_ID', 'NO_OF_VEHICLES', 'NO_PERSONS_KILLED','NO_PERSONS_INJ_2', 'NO_PERSONS_INJ_3', 'NO_PERSONS_NOT_INJ','NO_PERSONS', 'POLICE_ATTEND', 'ROAD_GEOMETRY', 'ROAD_GEOMETRY_DESC','SEVERITY', 'SPEED_ZONE', 'RMA'
#
# # 1 NF
# <b>Rules of 1st Normal Form</b>
# - Each table should contain a single value.
# - Each record needs to be unique.
#
# <b>Steps to take</b>
# - Separate repeating groups into their own table -> No repeating groups
#
#
# <b>Table form</b>
#
# ACCIDENT_INFO('ACCIDENT_NO', 'ACCIDENT_DATE', 'ACCIDENT_TIME', 'ACCIDENT_TYPE','ACCIDENT_TYPE_DESC', 'DAY_WEEK_DESC', 'DCA_CODE', 'DCA_DESC','LIGHT_CONDITION', 'NODE_ID', 'NO_OF_VEHICLES', 'NO_PERSONS_KILLED','NO_PERSONS_INJ_2', 'NO_PERSONS_INJ_3', 'NO_PERSONS_NOT_INJ','NO_PERSONS', 'POLICE_ATTEND', 'ROAD_GEOMETRY', 'ROAD_GEOMETRY_DESC','SEVERITY', 'SPEED_ZONE', 'RMA')
#
# <b>Check for partial dependencies </b>
# - PK is a single-attribute, hence no partial dependecies
# # 2NF
# <b>Rules of 2nd Normal Form</b>
# - The table should be in 1NF.
# - Primary Key does not functionally dependent on any subset of Candidate Key.
# - If the relation has a composite PK, then each non-key attribute must be fully dependent on the entire PK and not on a subset of the PK (i.e., there must be no partial dependency or augmentation).
#
# <b> Steps to take</b>
# * Remove partial dependencies
#
#
# <b>Table form</b>
#
# ACCIDENT_INFO('ACCIDENT_NO', 'ACCIDENT_DATE', 'ACCIDENT_TIME', 'ACCIDENT_TYPE','ACCIDENT_TYPE_DESC', 'DAY_WEEK_DESC', 'DCA_CODE', 'DCA_DESC','LIGHT_CONDITION', 'NODE_ID', 'NO_OF_VEHICLES', 'NO_PERSONS_KILLED','NO_PERSONS_INJ_2', 'NO_PERSONS_INJ_3', 'NO_PERSONS_NOT_INJ','NO_PERSONS', 'POLICE_ATTEND', 'ROAD_GEOMETRY', 'ROAD_GEOMETRY_DESC','SEVERITY', 'SPEED_ZONE', 'RMA')
#
# <b> Check for Transitivte Dependents </b>
#
# ACCIDENT_NO -> {ACCIDENT_TYPE} -> ACCIDENT_TYPE_DESC
#
# ACCIDENT_NO -> {DCA_CODE}      -> DCA_DESC
#
# ACCIDENT_NO -> {ROAD_GEOMETRY} -> ROAD_GEOMETRY_DESC
#
# # 3NF
#
# <b>Rules of 3rd Normal Form</b>
# - The tables should be in 2NF.
# - There will be no Transitive Dependency.
#
#
# <b>Table form</b>
#
# ACCIDENT_INFO(<b>'ACCIDENT_NO'</b>,'ACCIDENT_DATE','ACCIDENT_TIME','DAY_WEEK_DESC','POLICE_ATTEND','NO_PERSONS',
# 'NO_OF_VEHICLES','LIGHT_CONDITION','NO_PERSONS_KILLED','NO_PERSONS_INJ_2','NO_PERSONS_INJ_3','NO_PERSONS_NOT_INJ',
# 'SEVERITY', 'SPEED_ZONE', 'RMA','NODE_ID','DCA_CODE')
#
# ACCIDENT_TYPE(<b>'ACCIDENT_TYPE'</b>,'ACCIDENT_TYPE_DESC',)
#
# DCA_INFO(<b>'DCA_CODE'</b>, 'DCA_DESC',)
#
# ROAD_GEOMETRY(<b>'ROAD_GEOMETRY'</b>, 'ROAD_GEOMETRY_DESC')

# %%
accident_df.loc[accident_df["ACCIDENT_TYPE"]==9][["ACCIDENT_TYPE","ACCIDENT_TYPE_DESC"]]
# Out:
#         ACCIDENT_TYPE ACCIDENT_TYPE_DESC
# 4923                9     Other accident
# 5444                9     Other accident
# 5530                9     Other accident
# 7173                9     Other accident
# 9676                9     Other accident
# ...               ...                ...
# 164498              9     Other accident
# 165572              9     Other accident
# 165704              9     Other accident
# 166028              9     Other accident
# 166738              9     Other accident
#
# [171 rows x 2 columns]

# %%
# Retrieving Accident Type into one table.
Accident_Type = accident_df[["ACCIDENT_TYPE","ACCIDENT_TYPE_DESC"]].drop_duplicates().reset_index(drop=True)

Accident_Type
# Out:
#    ACCIDENT_TYPE                 ACCIDENT_TYPE_DESC
# 0              6  Vehicle overturned (no collision)
# 1              4      Collision with a fixed object
# 2              1             Collision with vehicle
# 3              8  No collision and no object struck
# 4              2                  Struck Pedestrian
# 5              3                      Struck animal
# 6              5   collision with some other object
# 7              7     Fall from or in moving vehicle
# 8              9                     Other accident

# %%
# Retrieving DCA unique codes into one table.
DCA_INFO = accident_df[["DCA_CODE","DCA_DESC"]].drop_duplicates().reset_index(drop=True)

DCA_INFO
# Out:
#     DCA_CODE                                           DCA_DESC
# 0        184            OUT OF CONTROL ON CARRIAGEWAY (ON BEND)
# 1        183           OFF LEFT BEND INTO OBJECT/PARKED VEHICLE
# 2        171    LEFT OFF CARRIAGEWAY INTO OBJECT/PARKED VEHICLE
# 3        173   RIGHT OFF CARRIAGEWAY INTO OBJECT/PARKED VEHICLE
# 4        160  VEHICLE COLLIDES WITH VEHICLE PARKED ON LEFT O...
# ..       ...                                                ...
# 76       122                                       LEFT THROUGH
# 77       165                                TEMPORARY ROADWORKS
# 78       124  RIGHT/RIGHT BOTH VEHs FROM OPPOSITE DIRECTIONS...
# 79       161                                      DOUBLE PARKED
# 80       125  LEFT/LEFT. BOTH VEHs FROM OPPOSITE DIRECTIONS ...
#
# [81 rows x 2 columns]

# %%
Road_Geometry = accident_df[["ROAD_GEOMETRY","ROAD_GEOMETRY_DESC"]].drop_duplicates().reset_index(drop=True)

Road_Geometry
# Out:
#    ROAD_GEOMETRY     ROAD_GEOMETRY_DESC
# 0              2         T intersection
# 1              5    Not at intersection
# 2              1     Cross intersection
# 3              4  Multiple intersection
# 4              9                Unknown
# 5              3         Y intersection
# 6              6               Dead end
# 7              8       Private property
# 8              7           Road closure

# %%
# Removing moved columns
accident_df = accident_df.drop(["DCA_DESC","ROAD_GEOMETRY_DESC","ACCIDENT_TYPE_DESC"],axis=1)

# %%
print("--------------------")                               
print(accident_df.columns)
print("--------------------")
print(Accident_Type.columns)
print("--------------------")
print(DCA_INFO.columns)
print("--------------------")
print(Road_Geometry.columns)
# Out:
# --------------------
# Index(['ACCIDENT_NO', 'ACCIDENT_DATE', 'ACCIDENT_TIME', 'ACCIDENT_TYPE',
#        'DAY_WEEK_DESC', 'DCA_CODE', 'LIGHT_CONDITION', 'NODE_ID',
#        'NO_OF_VEHICLES', 'NO_PERSONS_KILLED', 'NO_PERSONS_INJ_2',
#        'NO_PERSONS_INJ_3', 'NO_PERSONS_NOT_INJ', 'NO_PERSONS', 'POLICE_ATTEND',
#        'ROAD_GEOMETRY', 'SEVERITY', 'SPEED_ZONE', 'RMA'],
#       dtype='object')
# --------------------
# Index(['ACCIDENT_TYPE', 'ACCIDENT_TYPE_DESC'], dtype='object')
# --------------------
# Index(['DCA_CODE', 'DCA_DESC'], dtype='object')
# --------------------
# Index(['ROAD_GEOMETRY', 'ROAD_GEOMETRY_DESC'], dtype='object')

# %% [markdown]
# # -----------------------------------------------------------------------------------------

# %%
path = "./Resources/Cleanned/accident_event_df.csv"

accident_event_df = pd.read_csv(path)

# %%
accident_event_df.head(3)
# Out:
#     ACCIDENT_NO  EVENT_SEQ_NO EVENT_TYPE      EVENT_TYPE_DESC VEHICLE_1_ID  \
# 0  T20120003962             1          C            Collision            A
# 1  T20120003991             1          3  Ran off carriageway            A
# 2  T20120003991             2          C            Collision            A
#
#   VEHICLE_1_COLL_PT       VEHICLE 1 COLL PT DESC VEHICLE_2_ID  \
# 0                 1           Right front corner            B
# 1                 9  Not known or Not Applicable           NK
# 2                 1           Right front corner           NK
#
#   VEHICLE_2_COLL_PT       VEHICLE 2 COLL PT DESC PERSON_ID  OBJECT_TYPE  \
# 0                 5            Left front corner        NK           99
# 1                NK  Not known or Not Applicable        NK           99
# 2                NK  Not known or Not Applicable        NK            6
#
#                         OBJECT_TYPE_DESC
# 0                         Not Applicable
# 1                         Not Applicable
# 2  Traffic sign (no parking/no standing)

# %%
accident_event_df.columns
# Out:
# Index(['ACCIDENT_NO', 'EVENT_SEQ_NO', 'EVENT_TYPE', 'EVENT_TYPE_DESC',
#        'VEHICLE_1_ID', 'VEHICLE_1_COLL_PT', 'VEHICLE 1 COLL PT DESC',
#        'VEHICLE_2_ID', 'VEHICLE_2_COLL_PT', 'VEHICLE 2 COLL PT DESC',
#        'PERSON_ID', 'OBJECT_TYPE', 'OBJECT_TYPE_DESC'],
#       dtype='object')

# %%
accident_event_df.loc[accident_event_df["ACCIDENT_NO"]=="T20120004057"]
# Out:
#      ACCIDENT_NO  EVENT_SEQ_NO EVENT_TYPE    EVENT_TYPE_DESC VEHICLE_1_ID  \
# 9   T20120004057             1          C          Collision            A
# 10  T20120004057             2          2  Fell from vehicle            B
#
#    VEHICLE_1_COLL_PT       VEHICLE 1 COLL PT DESC VEHICLE_2_ID  \
# 9                  F                        Front            B
# 10                 9  Not known or Not Applicable           NK
#
#    VEHICLE_2_COLL_PT       VEHICLE 2 COLL PT DESC PERSON_ID  OBJECT_TYPE  \
# 9                  4            Right rear corner        NK           99
# 10                NK  Not known or Not Applicable        NK           99
#
#    OBJECT_TYPE_DESC
# 9    Not Applicable
# 10   Not Applicable

# %% [markdown]
# # Base Table
# 'ACCIDENT_NO', 'EVENT_SEQ_NO', 'EVENT_TYPE', 'EVENT_TYPE_DESC','VEHICLE_1_ID', 'VEHICLE_1_COLL_PT',
# 'VEHICLE 1 COLL PT DESC','VEHICLE_2_ID', 'VEHICLE_2_COLL_PT', 'VEHICLE 2 COLL PT DESC','PERSON_ID',
# 'OBJECT_TYPE', 'OBJECT_TYPE_DESC'
#
# # 1 NF
# <b>Rules of 1st Normal Form</b>
# - Each table should contain a single value.
# - Each record needs to be unique.
#
# <b>Steps to take</b>
# - Separate repeating groups into their own table -> No repeating groups
#
# Repeating groups
# accident_no can have multiple event_seq_no
#
# <b>Table form</b>
#
# ACCIDENT_EVENT(<b>'ACCIDENT_NO', 'EVENT_SEQ_NO'</b>, 'EVENT_TYPE', 'EVENT_TYPE_DESC',
# 'VEHICLE_1_ID', 'VEHICLE_1_COLL_PT', 'VEHICLE 1 COLL PT DESC','VEHICLE_2_ID', 'VEHICLE_2_COLL_PT', 'VEHICLE 2 COLL PT DESC','PERSON_ID','OBJECT_TYPE', 'OBJECT_TYPE_DESC')
#
#
# <b>Check for partial dependencies </b>
# - No partial dependencies, all non-key attributes depend on the composite primary key
#
#
# # 2NF
# <b>Rules of 2nd Normal Form</b>
# - The table should be in 1NF.
# - Primary Key does not functionally dependent on any subset of Candidate Key.
# - If the relation has a composite PK, then each non-key attribute must be fully dependent on the entire PK and not on a subset of the PK (i.e., there must be no partial dependency or augmentation).
#
# <b> Steps to take</b>
# * Remove partial dependencies
#
# <b>Table form</b>
#
# ACCIDENT_EVENT(<b>'ACCIDENT_NO', 'EVENT_SEQ_NO'</b>, 'EVENT_TYPE', 'EVENT_TYPE_DESC',
# 'VEHICLE_1_ID', 'VEHICLE_1_COLL_PT', 'VEHICLE 1 COLL PT DESC','VEHICLE_2_ID', 'VEHICLE_2_COLL_PT', 'VEHICLE 2 COLL PT DESC','PERSON_ID','OBJECT_TYPE', 'OBJECT_TYPE_DESC')
#
# <b> Check for Transitivte Dependents </b>
# {ACCIDENT-NO, EVENT_SEQ_NO} -> EVENT_TYPE -> EVENT_TYPE_DESC
# {ACCIDENT-NO, EVENT_SEQ_NO} -> OBJECT_TYPE -> OBJECT_TYPE_DESC
#
# # 3NF
#
# <b>Rules of 3rd Normal Form</b>
# - The tables should be in 2NF.
# - There will be no Transitive Dependency.
#
#
# <b>Table form</b>
#
#
# ACCIDENT_EVENT(<b>'ACCIDENT_NO', 'EVENT_SEQ_NO'</b>, 'EVENT_TYPE','VEHICLE_1_ID', 'VEHICLE_1_COLL_PT', ,'VEHICLE_2_ID', 'VEHICLE 2 COLL PT DESC', 'PERSON_ID', 'OBJECT_TYPE')
#
# OBJECT(<b>OBJECT_TYPE</b>, OBJECT_TYPE_DESC)
#
# EVENT_TYPE(<b>EVENT_TYPE</b>, EVENT_TYPE_DESC)
#
# VEHICLE_COL1(<b>VEHICLE_1_COLL_PT<b>,VEHICLE 1 COLL DESC)
#
# VEHICLE_COL1(<b>VEHICLE_2_COLL_PT<b>,VEHICLE 2 COLL DESC)

# %%
Object_Type = accident_event_df[["OBJECT_TYPE","OBJECT_TYPE_DESC"]].drop_duplicates().reset_index(drop=True)
Event_Type = accident_event_df[["EVENT_TYPE","EVENT_TYPE_DESC"]].drop_duplicates().reset_index(drop=True)
Vehicle_Coll1 = accident_event_df[["VEHICLE_1_COLL_PT","VEHICLE 1 COLL PT DESC"]].drop_duplicates().reset_index(drop=True)

Vehicle_Coll2 = accident_event_df[["VEHICLE_2_COLL_PT","VEHICLE 2 COLL PT DESC"]].drop_duplicates().reset_index(drop=True)

accident_event_df = accident_event_df.drop(["OBJECT_TYPE_DESC","EVENT_TYPE_DESC"],axis=1)

# %%
# Renaming column for concat later
Vehicle_Coll2= Vehicle_Coll2.rename(columns={"VEHICLE_2_COLL_PT":"VEHICLE_1_COLL_PT",
                                             "VEHICLE 2 COLL PT DESC":
                                             "VEHICLE 1 COLL PT DESC"})
# Combing both Coll PT tables into one table. 
Vehicle_Coll = pd.concat([Vehicle_Coll1,Vehicle_Coll2])
Vehicle_Coll = Vehicle_Coll.drop_duplicates().reset_index(drop=True).rename(columns={"VEHICLE_1_COLL_PT":"VEHICLE_COLL_PT",
                                                                                    "VEHICLE 1 COLL PT DESC":"VEHICLE COLL PT DESC"})
Vehicle_Coll
# Out:
#    VEHICLE_COLL_PT         VEHICLE COLL PT DESC
# 0                1           Right front corner
# 1                9  Not known or Not Applicable
# 2                2        Right side (forwards)
# 3                F                        Front
# 4                0                   Towed unit
# 5                T                     Top/Roof
# 6                4            Right rear corner
# 7                7        Left side (rearwards)
# 8                5            Left front corner
# 9                6         Left side (forwards)
# 10               3       Right side (rearwards)
# 11               8             Left rear corner
# 12               R                         Rear
# 13               U                Undercarriage
# 14               N                          NaN
# 15               S                      Sidecar
# 16              NK  Not known or Not Applicable

# %%
print("------------------")
print(accident_event_df.columns)
print("------------------")
print(Object_Type.columns)
print("------------------")
print(Event_Type.columns)
print("------------------")
print(Vehicle_Coll.columns)
# Out:
# ------------------
# Index(['ACCIDENT_NO', 'EVENT_SEQ_NO', 'EVENT_TYPE', 'VEHICLE_1_ID',
#        'VEHICLE_1_COLL_PT', 'VEHICLE 1 COLL PT DESC', 'VEHICLE_2_ID',
#        'VEHICLE_2_COLL_PT', 'VEHICLE 2 COLL PT DESC', 'PERSON_ID',
#        'OBJECT_TYPE'],
#       dtype='object')
# ------------------
# Index(['OBJECT_TYPE', 'OBJECT_TYPE_DESC'], dtype='object')
# ------------------
# Index(['EVENT_TYPE', 'EVENT_TYPE_DESC'], dtype='object')
# ------------------
# Index(['VEHICLE_COLL_PT', 'VEHICLE COLL PT DESC'], dtype='object')

# %% [markdown]
# # -----------------------------------------------------------------------------------------

# %%
path = "./Resources/Cleanned/accident_location_df.csv"

accident_location_df = pd.read_csv(path)

# %%
accident_location_df.head()
# Out:
#     ACCIDENT_NO       ROAD_NAME ROAD_TYPE ROAD_NAME_INT ROAD_TYPE_INT  \
# 0  T20120000060          LINMAX     COURT       WALLACE        AVENUE
# 1  T20120000082          DORSET      ROAD    ALLAMBANAN         DRIVE
# 2  T20120000090  CHURCHILL PARK     DRIVE      PARKSIDE     BOULEVARD
# 3  T20120000093         PRINCES   HIGHWAY       IRVINES          ROAD
# 4  T20120000104           DAVIS      ROAD       LEMARNE          ROAD
#
#   DIRECTION_LOCATION
# 0                 NW
# 1                  S
# 2                  E
# 3                 SW
# 4                  W

# %%
accident_location_df.columns
# Out:
# Index(['ACCIDENT_NO', 'ROAD_NAME', 'ROAD_TYPE', 'ROAD_NAME_INT',
#        'ROAD_TYPE_INT', 'DIRECTION_LOCATION'],
#       dtype='object')

# %% [markdown]
# # Base Table
# 'ACCIDENT_NO', 'ROAD_NAME', 'ROAD_TYPE', 'ROAD_NAME_INT','ROAD_TYPE_INT',
# 'DIRECTION_LOCATION',
#
#
# # 1 NF
# <b>Rules of 1st Normal Form</b>
# - Each table should contain a single value.
# - Each record needs to be unique.
#
# <b>Steps to take</b>
# - Separate repeating groups into their own table -> No repeating groups
#
# Repeating groups
# accident_no can have multiple event_seq_no
#
# <b>Table form</b>
#
# ACCIDENT_LOCATION(<b>'ACCIDENT_NO'</b>,'ROAD_NAME','ROAD_TYPE','ROAD_NAME_INT',
# 'ROAD_TYPE_INT', 'DIRECTION_LOCATION',)
#
#
#
# <b>Check for partial dependencies </b>
# - No partial dependencies, single attribute PK
#
#
# # 2NF
# <b>Rules of 2nd Normal Form</b>
# - The table should be in 1NF.
# - Primary Key does not functionally dependent on any subset of Candidate Key.
# - If the relation has a composite PK, then each non-key attribute must be fully dependent on the entire PK and not on a subset of the PK (i.e., there must be no partial dependency or augmentation).
#
# <b> Steps to take</b>
# * Remove partial dependencies
#
# <b>Table form</b>
#
# ACCIDENT_LOCATION(<b>'ACCIDENT_NO'</b>,'ROAD_NAME','ROAD_TYPE','ROAD_NAME_INT',
# 'ROAD_TYPE_INT', 'DIRECTION_LOCATION',)
#
#
# <b> Check for Transitivte Dependents </b>
#
# # 3NF
#
# <b>Rules of 3rd Normal Form</b>
# - The tables should be in 2NF.
# - There will be no Transitive Dependency.
#
#
# <b>Table form</b>
#
# ACCIDENT_LOCATION(<b>'ACCIDENT_NO'</b>,'ROAD_NAME','ROAD_TYPE','ROAD_NAME_INT',
# 'ROAD_TYPE_INT', 'DIRECTION_LOCATION',)

# %% [markdown]
# # -----------------------------------------------------------------------------------------

# %%
path = "./Resources/Cleanned/atmospheric_df.csv"

atmospheric_df = pd.read_csv(path)

# %%
atmospheric_df.head()
# Out:
#     ACCIDENT_NO  ATMOSPH_COND  ATMOSPH_COND_SEQ ATMOSPH_COND_DESC
# 0  T20130006765             1                 1             Clear
# 1  T20130006774             1                 1             Clear
# 2  T20130006803             1                 1             Clear
# 3  T20130006824             9                 1         Not known
# 4  T20130006833             1                 1             Clear

# %%
# Checking seq column 
atmospheric_df.loc[atmospheric_df["ATMOSPH_COND_SEQ"]==2]
# Out:
#          ACCIDENT_NO  ATMOSPH_COND  ATMOSPH_COND_SEQ ATMOSPH_COND_DESC
# 81      T20130007988             7                 2      Strong winds
# 140     T20120014278             7                 2      Strong winds
# 346     T20150014579             2                 2           Raining
# 837     T20140021635             7                 2      Strong winds
# 1449    T20150016493             2                 2           Raining
# ...              ...           ...               ...               ...
# 169279  T20120012289             7                 2      Strong winds
# 169281  T20120012292             7                 2      Strong winds
# 169330  T20120013087             7                 2      Strong winds
# 169333  T20120013110             7                 2      Strong winds
# 169348  T20120013374             2                 2           Raining
#
# [1770 rows x 4 columns]

# %%
atmospheric_df.columns
# Out:
# Index(['ACCIDENT_NO', 'ATMOSPH_COND', 'ATMOSPH_COND_SEQ', 'ATMOSPH_COND_DESC'], dtype='object')

# %% [markdown]
# # Existing Tables
# ACCIDENT_INFO(<b>'ACCIDENT_NO'</b>,'ACCIDENT_DATE','ACCIDENT_TIME','DAY_WEEK_DESC','POLICE_ATTEND','NO_PERSONS',
# 'NO_OF_VEHICLES','LIGHT_CONDITION','NO_PERSONS_KILLED','NO_PERSONS_INJ_2','NO_PERSONS_INJ_3','NO_PERSONS_NOT_INJ',
# 'SEVERITY', 'SPEED_ZONE', 'RMA','NODE_ID','DCA_CODE')
#
# ACCIDENT_TYPE(<b>'ACCIDENT_TYPE'</b>,'ACCIDENT_TYPE_DESC',)
#
# DCA_INFO(<b>'DCA_CODE'</b>, 'DCA_DESC',)
#
# ROAD_GEOMETRY(<b>'ROAD_GEOMETRY'</b>, 'ROAD_GEOMETRY_DESC')
#
# ACCIDENT_EVENT(<b>'ACCIDENT_NO', 'EVENT_SEQ_NO'</b>, 'EVENT_TYPE','VEHICLE_1_ID', 'VEHICLE_1_COLL_PT', 'VEHICLE 1 COLL PT DESC','VEHICLE_2_ID', 'VEHICLE_2_COLL_PT', 'VEHICLE 2 COLL PT DESC', 'PERSON_ID', 'OBJECT_TYPE')
#
# OBJECT(<b>OBJECT_TYPE</b>, OBJECT_TYPE_DESC)
#
# EVENT_TYPE(<b>EVENT_TYPE</b>, EVENT_TYPE_DESC)
#
# ACCIDENT_LOCATION(<b>'ACCIDENT_NO'</b>,'ROAD_NAME','ROAD_TYPE','ROAD_NAME_INT',
# 'ROAD_TYPE_INT', 'DIRECTION_LOCATION',)
#
# # Base Table
# 'ACCIDENT_NO', 'ATMOSPH_COND', 'ATMOSPH_COND_SEQ', 'ATMOSPH_COND_DESC'
#
#
# # 1 NF
# <b>Rules of 1st Normal Form</b>
# - Each table should contain a single value.
# - Each record needs to be unique.
#
# <b>Steps to take</b>
# - Separate repeating groups into their own table -> No repeating groups
#
# Repeating groups
# accident_no can have multiple event_seq_no
#
# <b>Table form</b>
#
# ATMOSHPERIC(<b>ACCIDENT_NO,ATMOSPH_COND_SEQ</b>, ATMOSPH_COND, ATMOSPH_COND_DESC)
#
# <b>Check for partial dependencies </b>
# - No partial dependencies, composite PK
#
#
# # 2NF
# <b>Rules of 2nd Normal Form</b>
# - The table should be in 1NF.
# - Primary Key does not functionally dependent on any subset of Candidate Key.
# - If the relation has a composite PK, then each non-key attribute must be fully dependent on the entire PK and not on a subset of the PK (i.e., there must be no partial dependency or augmentation).
#
# <b> Steps to take</b>
# * Remove partial dependencies
#
# <b>Table form</b>
#
# ATMOSHPERIC(<b>ACCIDENT_NO,ATMOSPH_COND_SEQ</b>, ATMOSPH_COND, ATMOSPH_COND_DESC)
#
#
# <b> Check for Transitivte Dependents </b>
# {ACCIDENT_NO,ATMOSPH_COND_SEQ} -> ATMOSPH_COND -> ATMOSPH_COND_DESC
#
# # 3NF
#
# <b>Rules of 3rd Normal Form</b>
# - The tables should be in 2NF.
# - There will be no Transitive Dependency.
#
#
# <b>Table form</b>
#
# ATMOSHPERIC(<b>ACCIDENT_NO,ATMOSPH_COND_SEQ</b>, ATMOSPH_COND)
#
# ATMOSPH_COND(<b>ATMOSPH_COND</b>, ATMOSPH_COND_DESC)

# %%
ATMOSPH_COND= atmospheric_df[["ATMOSPH_COND","ATMOSPH_COND_DESC"]].drop_duplicates().reset_index(drop=True)

atmospheric_df = atmospheric_df.drop(["ATMOSPH_COND_DESC"],axis=1)

# %%
print("--------------------")
print(atmospheric_df.columns)
print("--------------------")
print(ATMOSPH_COND.columns)
# Out:
# --------------------
# Index(['ACCIDENT_NO', 'ATMOSPH_COND', 'ATMOSPH_COND_SEQ'], dtype='object')
# --------------------
# Index(['ATMOSPH_COND', 'ATMOSPH_COND_DESC'], dtype='object')

# %% [markdown]
# # -----------------------------------------------------------------------------------------

# %%
path = "./Resources/Cleanned/node_df.csv"

node_df = pd.read_csv(path)

# %%
node_df.head()
# Out:
#     ACCIDENT_NO       LGA_NAME  DEG_URBAN_NAME   LATITUDE   LONGITUDE  \
# 0  T20220021115        LATROBE  RURAL_VICTORIA -38.188345  146.576115
# 1  T20220016471    STONNINGTON      MELB_URBAN -37.866454  145.049989
# 2  T20220011545     WELLINGTON  RURAL_VICTORIA -37.985367  146.733949
# 3  T20220009098        BENALLA  RURAL_VICTORIA -36.797963  145.866604
# 4  T20220017520  GOLDEN PLAINS     SMALL_TOWNS -38.021179  144.024292
#
#   POSTCODE_CRASH
# 0           3844
# 1           3145
# 2           3858
# 3             NK
# 4           3328

# %%
node_df.columns
# Out:
# Index(['ACCIDENT_NO', 'LGA_NAME', 'DEG_URBAN_NAME', 'LATITUDE', 'LONGITUDE',
#        'POSTCODE_CRASH'],
#       dtype='object')

# %%
node_df.groupby("LATITUDE").count().sort_values(by="LONGITUDE",ascending=False)
# Out:
#             ACCIDENT_NO  LGA_NAME  DEG_URBAN_NAME  LONGITUDE  POSTCODE_CRASH
# LATITUDE
# -37.810317           84        84              84         84              84
# -37.819613           74        74              74         74              74
# -37.812466           74        74              74         74              74
# -37.792260           64        64              64         64              64
# -37.811755           62        62              62         62              62
# ...                 ...       ...             ...        ...             ...
# -37.886470            1         1               1          1               1
# -37.886483            1         1               1          1               1
# -37.886495            1         1               1          1               1
# -37.886498            1         1               1          1               1
# -34.115694            1         1               1          1               1
#
# [114489 rows x 5 columns]

# %% [markdown]
# # Existing Tables
# ACCIDENT_INFO(<b>'ACCIDENT_NO'</b>,'ACCIDENT_DATE','ACCIDENT_TIME','DAY_WEEK_DESC','POLICE_ATTEND','NO_PERSONS',
# 'NO_OF_VEHICLES','LIGHT_CONDITION','NO_PERSONS_KILLED','NO_PERSONS_INJ_2','NO_PERSONS_INJ_3','NO_PERSONS_NOT_INJ',
# 'SEVERITY', 'SPEED_ZONE', 'RMA','NODE_ID','DCA_CODE')
#
# ACCIDENT_TYPE(<b>'ACCIDENT_TYPE'</b>,'ACCIDENT_TYPE_DESC',)
#
# DCA_INFO(<b>'DCA_CODE'</b>, 'DCA_DESC',)
#
# ROAD_GEOMETRY(<b>'ROAD_GEOMETRY'</b>, 'ROAD_GEOMETRY_DESC')
#
# ACCIDENT_EVENT(<b>'ACCIDENT_NO', 'EVENT_SEQ_NO'</b>, 'EVENT_TYPE','VEHICLE_1_ID', 'VEHICLE_1_COLL_PT', 'VEHICLE 1 COLL PT DESC','VEHICLE_2_ID', 'VEHICLE_2_COLL_PT', 'VEHICLE 2 COLL PT DESC', 'PERSON_ID', 'OBJECT_TYPE')
#
# OBJECT(<b>OBJECT_TYPE</b>, OBJECT_TYPE_DESC)
#
# EVENT_TYPE(<b>EVENT_TYPE</b>, EVENT_TYPE_DESC)
#
# ACCIDENT_LOCATION(<b>'ACCIDENT_NO'</b>,'ROAD_NAME','ROAD_TYPE','ROAD_NAME_INT',
# 'ROAD_TYPE_INT', 'DIRECTION_LOCATION',)
#
# ATMOSHPERIC(<b>ACCIDENT_NO,ATMOSPH_COND_SEQ</b>, ATMOSPH_COND)
#
# ATMOSPH_COND(<b>ATMOSPH_COND</b>, ATMOSPH_COND_DESC)
#
# # Base Table
# 'ACCIDENT_NO', 'LGA_NAME', 'DEG_URBAN_NAME', 'LATITUDE', 'LONGITUDE','POSTCODE_CRASH'
#
#
# # 1 NF
# <b>Rules of 1st Normal Form</b>
# - Each table should contain a single value.
# - Each record needs to be unique.
#
# <b>Steps to take</b>
# - Separate repeating groups into their own table -> No repeating groups
#
# Repeating groups
# accident_no can have multiple event_seq_no
#
# <b>Table form</b>
#
# NODE(<b>'ACCIDENT_NO'</b>, 'LGA_NAME', 'DEG_URBAN_NAME', 'LATITUDE', 'LONGITUDE','POSTCODE_CRASH')
#
# <b>Check for partial dependencies </b>
# - No partial dependencies, Single attribute PK
#
#
# # 2NF
# <b>Rules of 2nd Normal Form</b>
# - The table should be in 1NF.
# - Primary Key does not functionally dependent on any subset of Candidate Key.
# - If the relation has a composite PK, then each non-key attribute must be fully dependent on the entire PK and not on a subset of the PK (i.e., there must be no partial dependency or augmentation).
#
# <b> Steps to take</b>
#
# * Remove partial dependencies
#
# <b>Table form</b>
#
# NODE(<b>'ACCIDENT_NO'</b>, 'LGA_NAME', 'DEG_URBAN_NAME', 'LATITUDE', 'LONGITUDE','POSTCODE_CRASH')
#
#
# <b> Check for Transitivte Dependents </b>
#
# {ACCIDENT_NO} -> {LATITUDE,LONGITUDE} -> POSTCODE_CRASH
#  - Exception due to the nature of the relationship. postcode covers a range of latitude & longititudes
#
# # 3NF
#
# <b>Rules of 3rd Normal Form</b>
# - The tables should be in 2NF.
# - There will be no Transitive Dependency.
#
#
# <b>Table form</b>
#
# NODE(<b>'ACCIDENT_NO'</b>, 'LGA_NAME', 'DEG_URBAN_NAME', 'LATITUDE', 'LONGITUDE','POSTCODE_CRASH')

# %% [markdown]
# # -----------------------------------------------------------------------------------------

# %%
path = "./Resources/Cleanned/person_df.csv"

person_df = pd.read_csv(path)

# %%
person_df.head()
# Out:
#     ACCIDENT_NO PERSON_ID VEHICLE_ID SEX AGE_GROUP  INJ_LEVEL INJ_LEVEL_DESC  \
# 0  T20220027723         B          B   M     50-59          3   Other injury
# 1  T20210018500         A          A   M     30-39          3   Other injury
# 2  T20210026317        01          B   M       70+          4    Not injured
# 3  T20220000143         A          A   F     65-69          3   Other injury
# 4  T20170015017         A          A   M     40-49          4    Not injured
#
#   SEATING_POSITION  HELMET_BELT_WORN  ROAD_USER_TYPE ROAD_USER_TYPE_DESC  \
# 0                D                 9               2             Drivers
# 1                D                 1               2             Drivers
# 2               OR                 9               3          Passengers
# 3                D                 9               2             Drivers
# 4                D                 1               2             Drivers
#
#   LICENCE_STATE TAKEN_HOSPITAL EJECTED_CODE
# 0             V             NK          0.0
# 1             V             NK          0.0
# 2            NK             NK          9.0
# 3             V             NK          0.0
# 4             V             NK          0.0

# %%
person_df.columns
# Out:
# Index(['ACCIDENT_NO', 'PERSON_ID', 'VEHICLE_ID', 'SEX', 'AGE_GROUP',
#        'INJ_LEVEL', 'INJ_LEVEL_DESC', 'SEATING_POSITION', 'HELMET_BELT_WORN',
#        'ROAD_USER_TYPE', 'ROAD_USER_TYPE_DESC', 'LICENCE_STATE',
#        'TAKEN_HOSPITAL', 'EJECTED_CODE'],
#       dtype='object')

# %% [markdown]
# # Existing Tables
# ACCIDENT_INFO(<b>'ACCIDENT_NO'</b>,'ACCIDENT_DATE','ACCIDENT_TIME','DAY_WEEK_DESC','POLICE_ATTEND','NO_PERSONS',
# 'NO_OF_VEHICLES','LIGHT_CONDITION','NO_PERSONS_KILLED','NO_PERSONS_INJ_2','NO_PERSONS_INJ_3','NO_PERSONS_NOT_INJ',
# 'SEVERITY', 'SPEED_ZONE', 'RMA','NODE_ID','DCA_CODE')
#
# ACCIDENT_TYPE(<b>'ACCIDENT_TYPE'</b>,'ACCIDENT_TYPE_DESC',)
#
# DCA_INFO(<b>'DCA_CODE'</b>, 'DCA_DESC',)
#
# ROAD_GEOMETRY(<b>'ROAD_GEOMETRY'</b>, 'ROAD_GEOMETRY_DESC')
#
# ACCIDENT_EVENT(<b>'ACCIDENT_NO', 'EVENT_SEQ_NO'</b>, 'EVENT_TYPE','VEHICLE_1_ID', 'VEHICLE_1_COLL_PT', 'VEHICLE 1 COLL PT DESC','VEHICLE_2_ID', 'VEHICLE_2_COLL_PT', 'VEHICLE 2 COLL PT DESC', 'PERSON_ID', 'OBJECT_TYPE')
#
# OBJECT(<b>OBJECT_TYPE</b>, OBJECT_TYPE_DESC)
#
# EVENT_TYPE(<b>EVENT_TYPE</b>, EVENT_TYPE_DESC)
#
# ACCIDENT_LOCATION(<b>'ACCIDENT_NO'</b>,'ROAD_NAME','ROAD_TYPE','ROAD_NAME_INT',
# 'ROAD_TYPE_INT', 'DIRECTION_LOCATION',)
#
# ATMOSHPERIC(<b>ACCIDENT_NO,ATMOSPH_COND_SEQ</b>, ATMOSPH_COND)
#
# ATMOSPH_COND(<b>ATMOSPH_COND</b>, ATMOSPH_COND_DESC)
#
# NODE(<b>'ACCIDENT_NO'</b>, 'LGA_NAME', 'DEG_URBAN_NAME', 'LATITUDE', 'LONGITUDE','POSTCODE_CRASH')
#
# # Base Table
# 'ACCIDENT_NO', 'PERSON_ID', 'VEHICLE_ID', 'SEX', 'AGE_GROUP','INJ_LEVEL', 'INJ_LEVEL_DESC', 'SEATING_POSITION', 'HELMET_BELT_WORN','ROAD_USER_TYPE', 'ROAD_USER_TYPE_DESC', 'LICENCE_STATE','TAKEN_HOSPITAL', 'EJECTED_CODE'
#
#
# # 1 NF
# <b>Rules of 1st Normal Form</b>
# - Each table should contain a single value.
# - Each record needs to be unique.
#
# <b>Steps to take</b>
# - Separate repeating groups into their own table -> No repeating groups
#
# Repeating groups
# accident_no can have multiple vehicle ID
#
# <b>Table form</b>
#
# PERSON(<b>'ACCIDENT_NO','VEHICLE_ID' 'PERSON_ID'</b>, 'SEX', 'AGE_GROUP','INJ_LEVEL', 'INJ_LEVEL_DESC', 'SEATING_POSITION', 'HELMET_BELT_WORN','ROAD_USER_TYPE', 'ROAD_USER_TYPE_DESC', 'LICENCE_STATE','TAKEN_HOSPITAL', 'EJECTED_CODE')
#
# <b>Check for partial dependencies </b>
# - Sex, Age_Group are not partial dependencies due to the format of the data, Person_ID needs correlation with accident_no and vehicle_id to identify each person.
#
#
# # 2NF
# <b>Rules of 2nd Normal Form</b>
# - The table should be in 1NF.
# - Primary Key does not functionally dependent on any subset of Candidate Key.
# - If the relation has a composite PK, then each non-key attribute must be fully dependent on the entire PK and not on a subset of the PK (i.e., there must be no partial dependency or augmentation).
#
# <b> Steps to take</b>
#
# * Remove partial dependencies
#
# <b>Table form</b>
#
# PERSON(<b>'ACCIDENT_NO','VEHICLE_ID' 'PERSON_ID'</b>, 'SEX', 'AGE_GROUP','INJ_LEVEL', 'INJ_LEVEL_DESC', 'SEATING_POSITION', 'HELMET_BELT_WORN','ROAD_USER_TYPE', 'ROAD_USER_TYPE_DESC', 'LICENCE_STATE','TAKEN_HOSPITAL', 'EJECTED_CODE')
#
#
# <b> Check for Transitivte Dependents </b>
#
# {'ACCIDENT_NO','VEHICLE_ID' 'PERSON_ID'} -> INJ_LEVEL -> INJ_LEVEL_DESC
# {'ACCIDENT_NO','VEHICLE_ID' 'PERSON_ID'} -> ROAD_USER_TYPE -> ROAD_USER_TYPE_DESC
#
# # 3NF
#
# <b>Rules of 3rd Normal Form</b>
# - The tables should be in 2NF.
# - There will be no Transitive Dependency.
#
#
# <b>Table form</b>
#
# PERSON(<b>'ACCIDENT_NO','VEHICLE_ID' 'PERSON_ID'</b>, 'SEX', 'AGE_GROUP','INJ_LEVEL', , 'SEATING_POSITION', 'HELMET_BELT_WORN','ROAD_USER_TYPE', 'LICENCE_STATE','TAKEN_HOSPITAL', 'EJECTED_CODE')
#
# ROAD_USER(<b>'ROAD_USER_TYPE'</b>,'ROAD_USER_TYPE_DESC')
#
# INJ_LEVEL(<b>'INJ_LEVEL'</b>,'INJ_LEVEL_DESC')

# %%
Road_User = person_df[["ROAD_USER_TYPE","ROAD_USER_TYPE_DESC"]].drop_duplicates().reset_index(drop=True)
Inj_Level = person_df[["INJ_LEVEL","INJ_LEVEL_DESC"]].drop_duplicates().reset_index(drop=True)

person_df.drop(["ROAD_USER_TYPE_DESC","INJ_LEVEL_DESC"],axis=1)
# Out:
#          ACCIDENT_NO PERSON_ID VEHICLE_ID SEX AGE_GROUP  INJ_LEVEL  \
# 0       T20220027723         B          B   M     50-59          3
# 1       T20210018500         A          A   M     30-39          3
# 2       T20210026317        01          B   M       70+          4
# 3       T20220000143         A          A   F     65-69          3
# 4       T20170015017         A          A   M     40-49          4
# ...              ...       ...        ...  ..       ...        ...
# 390621  T20230021583         A          A   U   Unknown          4
# 390622  T20230021583         B          B   M     26-29          3
# 390623  T20230021516         B          B   M     40-49          4
# 390624  T20230021516         A          A   M     60-64          3
# 390625  T20230017113         A          A   F     30-39          4
#
#        SEATING_POSITION  HELMET_BELT_WORN  ROAD_USER_TYPE LICENCE_STATE  \
# 0                     D                 9               2             V
# 1                     D                 1               2             V
# 2                    OR                 9               3            NK
# 3                     D                 9               2             V
# 4                     D                 1               2             V
# ...                 ...               ...             ...           ...
# 390621               NK                 9               2             Z
# 390622                D                 6               6             V
# 390623                D                 1               2             V
# 390624                D                 1               2             Q
# 390625                D                 9               2             V
#
#        TAKEN_HOSPITAL EJECTED_CODE
# 0                  NK          0.0
# 1                  NK          0.0
# 2                  NK          9.0
# 3                  NK          0.0
# 4                  NK          0.0
# ...               ...          ...
# 390621             NK          9.0
# 390622             NK          0.0
# 390623             NK          0.0
# 390624             NK          0.0
# 390625             NK           NK
#
# [390626 rows x 12 columns]

# %%
print("----------------")
print(person_df.columns)
print("----------------")
print(Inj_Level.columns)
print("----------------")
print(Road_User.columns)
# Out:
# ----------------
# Index(['ACCIDENT_NO', 'PERSON_ID', 'VEHICLE_ID', 'SEX', 'AGE_GROUP',
#        'INJ_LEVEL', 'INJ_LEVEL_DESC', 'SEATING_POSITION', 'HELMET_BELT_WORN',
#        'ROAD_USER_TYPE', 'ROAD_USER_TYPE_DESC', 'LICENCE_STATE',
#        'TAKEN_HOSPITAL', 'EJECTED_CODE'],
#       dtype='object')
# ----------------
# Index(['INJ_LEVEL', 'INJ_LEVEL_DESC'], dtype='object')
# ----------------
# Index(['ROAD_USER_TYPE', 'ROAD_USER_TYPE_DESC'], dtype='object')

# %% [markdown]
# # -----------------------------------------------------------------------------------------

# %%
path = "./Resources/Cleanned/road_surface_df.csv"

road_surface_df = pd.read_csv(path)

# %%
road_surface_df.head()
# Out:
#     ACCIDENT_NO  SURFACE_COND SURFACE_COND_DESC  SURFACE_COND_SEQ
# 0  T20130012339             9              Unk.                 1
# 1  T20130012360             1               Dry                 1
# 2  T20130012370             1               Dry                 1
# 3  T20130012375             1               Dry                 1
# 4  T20130012390             2               Wet                 1

# %%
road_surface_df.columns
# Out:
# Index(['ACCIDENT_NO', 'SURFACE_COND', 'SURFACE_COND_DESC', 'SURFACE_COND_SEQ'], dtype='object')

# %% [markdown]
# # Existing Tables
# ACCIDENT_INFO(<b>'ACCIDENT_NO'</b>,'ACCIDENT_DATE','ACCIDENT_TIME','DAY_WEEK_DESC','POLICE_ATTEND','NO_PERSONS',
# 'NO_OF_VEHICLES','LIGHT_CONDITION','NO_PERSONS_KILLED','NO_PERSONS_INJ_2','NO_PERSONS_INJ_3','NO_PERSONS_NOT_INJ',
# 'SEVERITY', 'SPEED_ZONE', 'RMA','NODE_ID','DCA_CODE')
#
# ACCIDENT_TYPE(<b>'ACCIDENT_TYPE'</b>,'ACCIDENT_TYPE_DESC',)
#
# DCA_INFO(<b>'DCA_CODE'</b>, 'DCA_DESC',)
#
# ROAD_GEOMETRY(<b>'ROAD_GEOMETRY'</b>, 'ROAD_GEOMETRY_DESC')
#
# ACCIDENT_EVENT(<b>'ACCIDENT_NO', 'EVENT_SEQ_NO'</b>, 'EVENT_TYPE','VEHICLE_1_ID', 'VEHICLE_1_COLL_PT', 'VEHICLE 1 COLL PT DESC','VEHICLE_2_ID', 'VEHICLE_2_COLL_PT', 'VEHICLE 2 COLL PT DESC', 'PERSON_ID', 'OBJECT_TYPE')
#
# OBJECT(<b>OBJECT_TYPE</b>, OBJECT_TYPE_DESC)
#
# EVENT_TYPE(<b>EVENT_TYPE</b>, EVENT_TYPE_DESC)
#
# ACCIDENT_LOCATION(<b>'ACCIDENT_NO'</b>,'ROAD_NAME','ROAD_TYPE','ROAD_NAME_INT',
# 'ROAD_TYPE_INT', 'DIRECTION_LOCATION',)
#
# ATMOSHPERIC(<b>ACCIDENT_NO,ATMOSPH_COND_SEQ</b>, ATMOSPH_COND)
#
# ATMOSPH_COND(<b>ATMOSPH_COND</b>, ATMOSPH_COND_DESC)
#
# NODE(<b>'ACCIDENT_NO'</b>, 'LGA_NAME', 'DEG_URBAN_NAME', 'LATITUDE', 'LONGITUDE','POSTCODE_CRASH')
#
# PERSON(<b>'ACCIDENT_NO','VEHICLE_ID' 'PERSON_ID'</b>, 'SEX', 'AGE_GROUP','INJ_LEVEL', , 'SEATING_POSITION', 'HELMET_BELT_WORN','ROAD_USER_TYPE', 'LICENCE_STATE','TAKEN_HOSPITAL', 'EJECTED_CODE')
#
# ROAD_USER(<b>'ROAD_USER_TYPE'</b>,'ROAD_USER_TYPE_DESC')
#
# INJ_LEVEL(<b>'INJ_LEVEL'</b>,'INJ_LEVEL_DESC')
#
# # Base Table
# 'ACCIDENT_NO', 'SURFACE_COND', 'SURFACE_COND_DESC', 'SURFACE_COND_SEQ'
#
#
# # 1 NF
# <b>Rules of 1st Normal Form</b>
# - Each table should contain a single value.
# - Each record needs to be unique.
#
# <b>Steps to take</b>
# - Separate repeating groups into their own table -> No repeating groups
#
# Repeating groups
# accident_no can have multiple vehicle ID
#
# <b>Table form</b>
#
# ROAD_SURFACE(<b>'ACCIDENT_NO','SURFACE_COND_SEQ'</b>, 'SURFACE_COND', 'SURFACE_COND_DESC',)
#
# <b>Check for partial dependencies </b>
# - No partial dependencies, composite PK
#
#
# # 2NF
# <b>Rules of 2nd Normal Form</b>
# - The table should be in 1NF.
# - Primary Key does not functionally dependent on any subset of Candidate Key.
# - If the relation has a composite PK, then each non-key attribute must be fully dependent on the entire PK and not on a subset of the PK (i.e., there must be no partial dependency or augmentation).
#
# <b> Steps to take</b>
#
# * Remove partial dependencies
#
# <b>Table form</b>
#
# ROAD_SURFACE(<b>'ACCIDENT_NO','SURFACE_COND_SEQ'</b>, 'SURFACE_COND', 'SURFACE_COND_DESC',)
#
# <b> Check for Transitivte Dependents </b>
#
# {'ACCIDENT_NO','SURFACE_COND_SEQ'} -> Surface_cond -> surface_cond_desc
#
# # 3NF
#
# <b>Rules of 3rd Normal Form</b>
# - The tables should be in 2NF.
# - There will be no Transitive Dependency.
#
#
# <b>Table form</b>
#
# ROAD_SURFACE(<b>'ACCIDENT_NO','SURFACE_COND_SEQ'</b>, 'SURFACE_COND')
#
#
# SURFACE_COND(<b>'SURFACE_COND'</b>, 'SURFACE_COND_DESC')

# %%
Surface_Cond = road_surface_df[["SURFACE_COND","SURFACE_COND_DESC"]].drop_duplicates().reset_index(drop=True)
road_surface_df = road_surface_df.drop(["SURFACE_COND_DESC"],axis=1)

# %%
print("----------------")
print(road_surface_df.columns)
print("----------------")
print(Surface_Cond.columns)
# Out:
# ----------------
# Index(['ACCIDENT_NO', 'SURFACE_COND', 'SURFACE_COND_SEQ'], dtype='object')
# ----------------
# Index(['SURFACE_COND', 'SURFACE_COND_DESC'], dtype='object')

# %% [markdown]
# # -----------------------------------------------------------------------------------------

# %%
path = "./Resources/Cleanned/sub_dca_df.csv"

sub_dca_df = pd.read_csv(path)

# %%
sub_dca_df.head()
# Out:
#     ACCIDENT_NO SUB_DCA_CODE  SUB_DCA_SEQ         SUB_DCA_CODE_DESC
# 0  T20120023069          NRQ            1              Not Required
# 1  T20120023107          L04            1  Road curved at mid-block
# 2  T20120023147          N01            1              Intersection
# 3  T20120023151          NRQ            1              Not Required
# 4  T20120023171          NRQ            1              Not Required

# %%
sub_dca_df.loc[sub_dca_df["ACCIDENT_NO"]=="T20120023440"]
# Out:
#         ACCIDENT_NO SUB_DCA_CODE  SUB_DCA_SEQ            SUB_DCA_CODE_DESC
# 10     T20120023440          Q04            2                  Embankments
# 6585   T20120023440          V01            1    No vehicle mounted/struck
# 29606  T20120023440          W02            3  Leaves carriageway to right

# %%
sub_dca_df.columns
# Out:
# Index(['ACCIDENT_NO', 'SUB_DCA_CODE', 'SUB_DCA_SEQ', 'SUB_DCA_CODE_DESC'], dtype='object')

# %% [markdown]
# # Existing Tables
# ACCIDENT_INFO(<b>'ACCIDENT_NO'</b>,'ACCIDENT_DATE','ACCIDENT_TIME','DAY_WEEK_DESC','POLICE_ATTEND','NO_PERSONS',
# 'NO_OF_VEHICLES','LIGHT_CONDITION','NO_PERSONS_KILLED','NO_PERSONS_INJ_2','NO_PERSONS_INJ_3','NO_PERSONS_NOT_INJ',
# 'SEVERITY', 'SPEED_ZONE', 'RMA','NODE_ID','DCA_CODE')
#
# ACCIDENT_TYPE(<b>'ACCIDENT_TYPE'</b>,'ACCIDENT_TYPE_DESC',)
#
# DCA_INFO(<b>'DCA_CODE'</b>, 'DCA_DESC',)
#
# ROAD_GEOMETRY(<b>'ROAD_GEOMETRY'</b>, 'ROAD_GEOMETRY_DESC')
#
# ACCIDENT_EVENT(<b>'ACCIDENT_NO', 'EVENT_SEQ_NO'</b>, 'EVENT_TYPE','VEHICLE_1_ID', 'VEHICLE_1_COLL_PT', 'VEHICLE 1 COLL PT DESC','VEHICLE_2_ID', 'VEHICLE_2_COLL_PT', 'VEHICLE 2 COLL PT DESC', 'PERSON_ID', 'OBJECT_TYPE')
#
# OBJECT(<b>OBJECT_TYPE</b>, OBJECT_TYPE_DESC)
#
# EVENT_TYPE(<b>EVENT_TYPE</b>, EVENT_TYPE_DESC)
#
# ACCIDENT_LOCATION(<b>'ACCIDENT_NO'</b>,'ROAD_NAME','ROAD_TYPE','ROAD_NAME_INT',
# 'ROAD_TYPE_INT', 'DIRECTION_LOCATION',)
#
# ATMOSHPERIC(<b>ACCIDENT_NO,ATMOSPH_COND_SEQ</b>, ATMOSPH_COND)
#
# ATMOSPH_COND(<b>ATMOSPH_COND</b>, ATMOSPH_COND_DESC)
#
# NODE(<b>'ACCIDENT_NO'</b>, 'LGA_NAME', 'DEG_URBAN_NAME', 'LATITUDE', 'LONGITUDE','POSTCODE_CRASH')
#
# PERSON(<b>'ACCIDENT_NO','VEHICLE_ID' 'PERSON_ID'</b>, 'SEX', 'AGE_GROUP','INJ_LEVEL', , 'SEATING_POSITION', 'HELMET_BELT_WORN','ROAD_USER_TYPE', 'LICENCE_STATE','TAKEN_HOSPITAL', 'EJECTED_CODE')
#
# ROAD_USER(<b>'ROAD_USER_TYPE'</b>,'ROAD_USER_TYPE_DESC')
#
# INJ_LEVEL(<b>'INJ_LEVEL'</b>,'INJ_LEVEL_DESC')
#
# ROAD_SURFACE(<b>'ACCIDENT_NO','SURFACE_COND_SEQ'</b>, 'SURFACE_COND')
#
# SURFACE_COND(<b>'SURFACE_COND'</b>, 'SURFACE_COND_DESC')
#
# # Base Table
# 'ACCIDENT_NO', 'SUB_DCA_CODE', 'SUB_DCA_SEQ', 'SUB_DCA_CODE_DESC'
#
#
# # 1 NF
# <b>Rules of 1st Normal Form</b>
# - Each table should contain a single value.
# - Each record needs to be unique.
#
# <b>Steps to take</b>
# - Separate repeating groups into their own table -> No repeating groups
#
# Repeating groups
# accident_no can have multiple vehicle ID
#
# <b>Table form</b>
#
# SUB_DCA(<b>'ACCIDENT_NO', 'SUB_DCA_SEQ'</b>, 'SUB_DCA_CODE', 'SUB_DCA_CODE_DESC')
#
# <b>Check for partial dependencies </b>
# - No partial dependencies, composite PK
#
#
# # 2NF
# <b>Rules of 2nd Normal Form</b>
# - The table should be in 1NF.
# - Primary Key does not functionally dependent on any subset of Candidate Key.
# - If the relation has a composite PK, then each non-key attribute must be fully dependent on the entire PK and not on a subset of the PK (i.e., there must be no partial dependency or augmentation).
#
# <b> Steps to take</b>
#
# * Remove partial dependencies
#
# <b>Table form</b>
#
# SUB_DCA(<b>'ACCIDENT_NO', 'SUB_DCA_SEQ'</b>, 'SUB_DCA_CODE', 'SUB_DCA_CODE_DESC')
#
# <b> Check for Transitivte Dependents </b>
#
# {'ACCIDENT_NO', 'SUB_DCA_SEQ'} -> 'SUB_DCA_CODE' -> 'SUB_DCA_CODE_DESC'
#
# # 3NF
#
# <b>Rules of 3rd Normal Form</b>
# - The tables should be in 2NF.
# - There will be no Transitive Dependency.
#
#
# <b>Table form</b>
#
# SUB_DCA(<b>'ACCIDENT_NO', 'SUB_DCA_SEQ'</b>, 'SUB_DCA_CODE', 'SUB_DCA_CODE_DESC')
#
#
# SUB_DCA_CODE(<b>'SUB_DCA_CODE'</b>, 'SUB_DCA_CODE_DESC')

# %%
Sub_DCA_Code = sub_dca_df[["SUB_DCA_CODE","SUB_DCA_CODE_DESC"]].drop_duplicates().reset_index(drop=True)

sub_dca_df = sub_dca_df.drop(["SUB_DCA_CODE_DESC"],axis=1)

# %%
print("--------------")
print(sub_dca_df.columns)
print("----------------")
print(Sub_DCA_Code.columns)
# Out:
# --------------
# Index(['ACCIDENT_NO', 'SUB_DCA_CODE', 'SUB_DCA_SEQ'], dtype='object')
# ----------------
# Index(['SUB_DCA_CODE', 'SUB_DCA_CODE_DESC'], dtype='object')

# %% [markdown]
# # -----------------------------------------------------------------------------------------

# %%
path = "./Resources/Cleanned/vehicle_df.csv"

vehicle_df = pd.read_csv(path)

# %%
vehicle_df.head()
# Out:
#     ACCIDENT_NO VEHICLE_ID  VEHICLE_YEAR_MANUF  VEHICLE_DCA_CODE  \
# 0  T20120000009          A              1996.0               1.0
# 1  T20120000012          A              2002.0               1.0
# 2  T20120000012          B              1988.0               2.0
# 3  T20120000013          A              1997.0               1.0
# 4  T20120000013          B              2010.0               2.0
#
#   INITIAL_DIRECTION  ROAD_SURFACE_TYPE ROAD_SURFACE_TYPE_DESC REG_STATE  \
# 0                 E                1.0                  Paved         V
# 1                 W                1.0                  Paved         V
# 2                 S                1.0                  Paved         V
# 3                 N                1.0                  Paved         V
# 4                 N                1.0                  Paved         V
#
#   VEHICLE_BODY_STYLE VEHICLE_MAKE  ... TRAILER_TYPE  VEHICLE_COLOUR_1  \
# 0              SEDAN       HOLDEN  ...            H               WHI
# 1              SEDAN       HOLDEN  ...            H               BLU
# 2              SEDAN       TOYOTA  ...            H               WHI
# 3              SEDAN       MITSUB  ...            H               GLD
# 4              WAGON       TOYOTA  ...            H               BLK
#
#   VEHICLE_COLOUR_2  CAUGHT_FIRE INITIAL_IMPACT  LAMPS  LEVEL_OF_DAMAGE  \
# 0               ZZ          2.0              1    1.0                5
# 1               ZZ          2.0              1    1.0                2
# 2               ZZ          2.0              5    9.0                4
# 3               ZZ          2.0              5    1.0                4
# 4               ZZ          2.0              4    2.0                4
#
#    TOWED_AWAY_FLAG  TRAFFIC_CONTROL  TRAFFIC_CONTROL_DESC
# 0              1.0              0.0            No control
# 1              2.0              1.0        Stop-go lights
# 2              1.0              1.0        Stop-go lights
# 3              1.0              0.0            No control
# 4              2.0              0.0            No control
#
# [5 rows x 33 columns]

# %%
vehicle_df.columns
# Out:
# Index(['ACCIDENT_NO', 'VEHICLE_ID', 'VEHICLE_YEAR_MANUF', 'VEHICLE_DCA_CODE',
#        'INITIAL_DIRECTION', 'ROAD_SURFACE_TYPE', 'ROAD_SURFACE_TYPE_DESC',
#        'REG_STATE', 'VEHICLE_BODY_STYLE', 'VEHICLE_MAKE', 'VEHICLE_MODEL',
#        'VEHICLE_TYPE', 'VEHICLE_TYPE_DESC', 'VEHICLE_WEIGHT', 'FUEL_TYPE',
#        'NO_OF_WHEELS', 'NO_OF_CYLINDERS', 'SEATING_CAPACITY',
#        'TOTAL_NO_OCCUPANTS', 'CARRY_CAPACITY', 'FINAL_DIRECTION',
#        'DRIVER_INTENT', 'VEHICLE_MOVEMENT', 'TRAILER_TYPE', 'VEHICLE_COLOUR_1',
#        'VEHICLE_COLOUR_2', 'CAUGHT_FIRE', 'INITIAL_IMPACT', 'LAMPS',
#        'LEVEL_OF_DAMAGE', 'TOWED_AWAY_FLAG', 'TRAFFIC_CONTROL',
#        'TRAFFIC_CONTROL_DESC'],
#       dtype='object')

# %%
vehicle_df[['VEHICLE_BODY_STYLE', 'VEHICLE_MAKE', 'VEHICLE_MODEL',
       'VEHICLE_TYPE', 'VEHICLE_TYPE_DESC', 'VEHICLE_WEIGHT', 'FUEL_TYPE',
       'NO_OF_WHEELS', 'NO_OF_CYLINDERS', 'SEATING_CAPACITY',
       'TOTAL_NO_OCCUPANTS', 'CARRY_CAPACITY']]
# Out:
#        VEHICLE_BODY_STYLE VEHICLE_MAKE VEHICLE_MODEL  VEHICLE_TYPE  \
# 0                   SEDAN       HOLDEN        ACCLAI             1
# 1                   SEDAN       HOLDEN        MONARO             1
# 2                   SEDAN       TOYOTA            NK             1
# 3                   SEDAN       MITSUB         MAGNA             1
# 4                   WAGON       TOYOTA            NK             2
# ...                   ...          ...           ...           ...
# 304724              SEDAN       SUZUKI         SWIFT             1
# 304725              WAGON         JEEP        COMPAS             2
# 304726              SEDAN         FORD           XR6             1
# 304727              SEDAN       TOYOTA        COROLL             1
# 304728                 NK           NK            NK            13
#
#        VEHICLE_TYPE_DESC  VEHICLE_WEIGHT FUEL_TYPE  NO_OF_WHEELS  \
# 0                    Car             0.0         P           4.0
# 1                    Car             0.0         P           4.0
# 2                    Car          1450.0         P           4.0
# 3                    Car             0.0         P           4.0
# 4          Station Wagon             0.0         P           4.0
# ...                  ...             ...       ...           ...
# 304724               Car             0.0         P           4.0
# 304725     Station Wagon             0.0         P           4.0
# 304726               Car             0.0         P           4.0
# 304727               Car             0.0         P           4.0
# 304728           Bicycle             0.0        NK           0.0
#
#         NO_OF_CYLINDERS  SEATING_CAPACITY  TOTAL_NO_OCCUPANTS  CARRY_CAPACITY
# 0                   6.0               5.0                 2.0             0.0
# 1                   8.0               4.0                 2.0             0.0
# 2                   4.0               5.0                 1.0           300.0
# 3                   4.0               5.0                 1.0             0.0
# 4                   6.0               7.0                 0.0             0.0
# ...                 ...               ...                 ...             ...
# 304724              4.0               5.0                 1.0             0.0
# 304725              4.0               5.0                 1.0             0.0
# 304726              6.0               5.0                 1.0             0.0
# 304727              4.0               5.0                 1.0             0.0
# 304728              0.0               0.0                 1.0             0.0
#
# [304729 rows x 12 columns]

# %% [markdown]
# # Existing Tables
# ACCIDENT_INFO(<b>'ACCIDENT_NO'</b>,'ACCIDENT_DATE','ACCIDENT_TIME','DAY_WEEK_DESC','POLICE_ATTEND','NO_PERSONS',
# 'NO_OF_VEHICLES','LIGHT_CONDITION','NO_PERSONS_KILLED','NO_PERSONS_INJ_2','NO_PERSONS_INJ_3','NO_PERSONS_NOT_INJ',
# 'SEVERITY', 'SPEED_ZONE', 'RMA','NODE_ID','DCA_CODE')
#
# ACCIDENT_TYPE(<b>'ACCIDENT_TYPE'</b>,'ACCIDENT_TYPE_DESC',)
#
# DCA_INFO(<b>'DCA_CODE'</b>, 'DCA_DESC',)
#
# ROAD_GEOMETRY(<b>'ROAD_GEOMETRY'</b>, 'ROAD_GEOMETRY_DESC')
#
# ACCIDENT_EVENT(<b>'ACCIDENT_NO', 'EVENT_SEQ_NO'</b>, 'EVENT_TYPE','VEHICLE_1_ID', 'VEHICLE_1_COLL_PT', 'VEHICLE 1 COLL PT DESC','VEHICLE_2_ID', 'VEHICLE_2_COLL_PT', 'VEHICLE 2 COLL PT DESC', 'PERSON_ID', 'OBJECT_TYPE')
#
# OBJECT(<b>OBJECT_TYPE</b>, OBJECT_TYPE_DESC)
#
# EVENT_TYPE(<b>EVENT_TYPE</b>, EVENT_TYPE_DESC)
#
# ACCIDENT_LOCATION(<b>'ACCIDENT_NO'</b>,'ROAD_NAME','ROAD_TYPE','ROAD_NAME_INT',
# 'ROAD_TYPE_INT', 'DIRECTION_LOCATION',)
#
# ATMOSHPERIC(<b>ACCIDENT_NO,ATMOSPH_COND_SEQ</b>, ATMOSPH_COND)
#
# ATMOSPH_COND(<b>ATMOSPH_COND</b>, ATMOSPH_COND_DESC)
#
# NODE(<b>'ACCIDENT_NO'</b>, 'LGA_NAME', 'DEG_URBAN_NAME', 'LATITUDE', 'LONGITUDE','POSTCODE_CRASH')
#
# PERSON(<b>'ACCIDENT_NO','VEHICLE_ID' 'PERSON_ID'</b>, 'SEX', 'AGE_GROUP','INJ_LEVEL', , 'SEATING_POSITION', 'HELMET_BELT_WORN','ROAD_USER_TYPE', 'LICENCE_STATE','TAKEN_HOSPITAL', 'EJECTED_CODE')
#
# ROAD_USER(<b>'ROAD_USER_TYPE'</b>,'ROAD_USER_TYPE_DESC')
#
# INJ_LEVEL(<b>'INJ_LEVEL'</b>,'INJ_LEVEL_DESC')
#
# ROAD_SURFACE(<b>'ACCIDENT_NO','SURFACE_COND_SEQ'</b>, 'SURFACE_COND')
#
# SURFACE_COND(<b>'SURFACE_COND'</b>, 'SURFACE_COND_DESC')
#
# SUB_DCA(<b>'ACCIDENT_NO', 'SUB_DCA_SEQ'</b>, 'SUB_DCA_CODE', 'SUB_DCA_CODE_DESC')
#
#
# SUB_DCA_CODE(<b>'SUB_DCA_CODE'</b>, 'SUB_DCA_CODE_DESC')
#
# # Base Table
# 'ACCIDENT_NO', 'VEHICLE_ID', 'VEHICLE_YEAR_MANUF', 'VEHICLE_DCA_CODE',
#        'INITIAL_DIRECTION', 'ROAD_SURFACE_TYPE', 'ROAD_SURFACE_TYPE_DESC',
#        'REG_STATE', 'VEHICLE_BODY_STYLE', 'VEHICLE_MAKE', 'VEHICLE_MODEL',
#        'VEHICLE_TYPE', 'VEHICLE_TYPE_DESC', 'VEHICLE_WEIGHT', 'FUEL_TYPE',
#        'NO_OF_WHEELS', 'NO_OF_CYLINDERS', 'SEATING_CAPACITY',
#        'TOTAL_NO_OCCUPANTS', 'CARRY_CAPACITY', 'FINAL_DIRECTION',
#        'DRIVER_INTENT', 'VEHICLE_MOVEMENT', 'TRAILER_TYPE', 'VEHICLE_COLOUR_1',
#        'VEHICLE_COLOUR_2', 'CAUGHT_FIRE', 'INITIAL_IMPACT', 'LAMPS',
#        'LEVEL_OF_DAMAGE', 'TOWED_AWAY_FLAG', 'TRAFFIC_CONTROL',
#        'TRAFFIC_CONTROL_DESC'
#
#
# # 1 NF
# <b>Rules of 1st Normal Form</b>
# - Each table should contain a single value.
# - Each record needs to be unique.
#
# <b>Steps to take</b>
# - Separate repeating groups into their own table -> No repeating groups
#
# Repeating groups
# accident_no can have multiple vehicle ID
#
# <b>Table form</b>
#
# Vehicle(<b>'ACCIDENT_NO', 'VEHICLE_ID'</b>, 'VEHICLE_YEAR_MANUF', 'VEHICLE_DCA_CODE',
#        'INITIAL_DIRECTION', 'ROAD_SURFACE_TYPE', 'ROAD_SURFACE_TYPE_DESC',
#        'REG_STATE', 'VEHICLE_BODY_STYLE', 'VEHICLE_MAKE', 'VEHICLE_MODEL',
#        'VEHICLE_TYPE', 'VEHICLE_TYPE_DESC', 'VEHICLE_WEIGHT', 'FUEL_TYPE',
#        'NO_OF_WHEELS', 'NO_OF_CYLINDERS', 'SEATING_CAPACITY',
#        'TOTAL_NO_OCCUPANTS', 'CARRY_CAPACITY', 'FINAL_DIRECTION',
#        'DRIVER_INTENT', 'VEHICLE_MOVEMENT', 'TRAILER_TYPE', 'VEHICLE_COLOUR_1',
#        'VEHICLE_COLOUR_2', 'CAUGHT_FIRE', 'INITIAL_IMPACT', 'LAMPS',
#        'LEVEL_OF_DAMAGE', 'TOWED_AWAY_FLAG', 'TRAFFIC_CONTROL',
#        'TRAFFIC_CONTROL_DESC')
#
# <b>Check for partial dependencies </b>
# - No partial dependencies, composite PK
#
#
# # 2NF
# <b>Rules of 2nd Normal Form</b>
# - The table should be in 1NF.
# - Primary Key does not functionally dependent on any subset of Candidate Key.
# - If the relation has a composite PK, then each non-key attribute must be fully dependent on the entire PK and not on a subset of the PK (i.e., there must be no partial dependency or augmentation).
#
# <b> Steps to take</b>
#
# * Remove partial dependencies
#
# <b>Table form</b>
#
# Vehicle(<b>'ACCIDENT_NO', 'VEHICLE_ID'</b>, 'VEHICLE_YEAR_MANUF', 'VEHICLE_DCA_CODE',
#        'INITIAL_DIRECTION', 'ROAD_SURFACE_TYPE', 'ROAD_SURFACE_TYPE_DESC',
#        'REG_STATE', 'VEHICLE_BODY_STYLE', 'VEHICLE_MAKE', 'VEHICLE_MODEL',
#        'VEHICLE_TYPE', 'VEHICLE_TYPE_DESC', 'VEHICLE_WEIGHT', 'FUEL_TYPE',
#        'NO_OF_WHEELS', 'NO_OF_CYLINDERS', 'SEATING_CAPACITY',
#        'TOTAL_NO_OCCUPANTS', 'CARRY_CAPACITY', 'FINAL_DIRECTION',
#        'DRIVER_INTENT', 'VEHICLE_MOVEMENT', 'TRAILER_TYPE', 'VEHICLE_COLOUR_1',
#        'VEHICLE_COLOUR_2', 'CAUGHT_FIRE', 'INITIAL_IMPACT', 'LAMPS',
#        'LEVEL_OF_DAMAGE', 'TOWED_AWAY_FLAG', 'TRAFFIC_CONTROL',
#        'TRAFFIC_CONTROL_DESC')
#
# <b> Check for Transitivte Dependents </b>
#
# {'ACCIDENT_NO', 'VEHICLE_ID'} -> TRAFFIC_CONTROL   -> TRAFFIC_CONTROL_DESC
# {'ACCIDENT_NO', 'VEHICLE_ID'} -> ROAD_SURFACE_TYPE -> ROAD_SURFACE_TYPE_DESC
#
# # 3NF
#
# <b>Rules of 3rd Normal Form</b>
# - The tables should be in 2NF.
# - There will be no Transitive Dependency.
#
#
# <b>Table form</b>
#
# VEHICLE(<b>'ACCIDENT_NO', 'VEHICLE_ID'</b>, 'VEHICLE_YEAR_MANUF', 'VEHICLE_DCA_CODE',
#        'INITIAL_DIRECTION', 'ROAD_SURFACE_TYPE', 'ROAD_SURFACE_TYPE_DESC',
#        'REG_STATE', 'VEHICLE_BODY_STYLE', 'VEHICLE_MAKE', 'VEHICLE_MODEL',
#        'VEHICLE_TYPE', 'VEHICLE_TYPE_DESC', 'VEHICLE_WEIGHT', 'FUEL_TYPE',
#        'NO_OF_WHEELS', 'NO_OF_CYLINDERS', 'SEATING_CAPACITY',
#        'TOTAL_NO_OCCUPANTS', 'CARRY_CAPACITY', 'FINAL_DIRECTION',
#        'DRIVER_INTENT', 'VEHICLE_MOVEMENT', 'TRAILER_TYPE', 'VEHICLE_COLOUR_1',
#        'VEHICLE_COLOUR_2', 'CAUGHT_FIRE', 'INITIAL_IMPACT', 'LAMPS',
#        'LEVEL_OF_DAMAGE', 'TOWED_AWAY_FLAG', 'TRAFFIC_CONTROL')
#
#
# TRAFFIC_CONTROL(<b>'TRAFFIC_CONTROL'</b>,'TRAFFIC_CONTROL_DESC')
#
# ROAD_SURFACE(<b>ROAD_SURFACE_TYPE</b>, ROAD_SURFACE_TYPE_DESC)

# %%
Traffic_Control = vehicle_df[["TRAFFIC_CONTROL","TRAFFIC_CONTROL_DESC"]].drop_duplicates().reset_index(drop=True)

Road_Surface = vehicle_df[["ROAD_SURFACE_TYPE","ROAD_SURFACE_TYPE_DESC"]].drop_duplicates().reset_index(drop=True)

vehicle_df = vehicle_df.drop(["TRAFFIC_CONTROL_DESC","ROAD_SURFACE_TYPE_DESC"],axis=1)

# %%
print("-------------------")
print(vehicle_df.columns)
print("-------------------")
print(Traffic_Control.columns)
print("-------------------")
print(Road_Surface.columns)
# Out:
# -------------------
# Index(['ACCIDENT_NO', 'VEHICLE_ID', 'VEHICLE_YEAR_MANUF', 'VEHICLE_DCA_CODE',
#        'INITIAL_DIRECTION', 'ROAD_SURFACE_TYPE', 'REG_STATE',
#        'VEHICLE_BODY_STYLE', 'VEHICLE_MAKE', 'VEHICLE_MODEL', 'VEHICLE_TYPE',
#        'VEHICLE_TYPE_DESC', 'VEHICLE_WEIGHT', 'FUEL_TYPE', 'NO_OF_WHEELS',
#        'NO_OF_CYLINDERS', 'SEATING_CAPACITY', 'TOTAL_NO_OCCUPANTS',
#        'CARRY_CAPACITY', 'FINAL_DIRECTION', 'DRIVER_INTENT',
#        'VEHICLE_MOVEMENT', 'TRAILER_TYPE', 'VEHICLE_COLOUR_1',
#        'VEHICLE_COLOUR_2', 'CAUGHT_FIRE', 'INITIAL_IMPACT', 'LAMPS',
#        'LEVEL_OF_DAMAGE', 'TOWED_AWAY_FLAG', 'TRAFFIC_CONTROL'],
#       dtype='object')
# -------------------
# Index(['TRAFFIC_CONTROL', 'TRAFFIC_CONTROL_DESC'], dtype='object')
# -------------------
# Index(['ROAD_SURFACE_TYPE', 'ROAD_SURFACE_TYPE_DESC'], dtype='object')

# %% [markdown]
# # -----------------------------------------------------------------------------------------

# %% [markdown]
# ACCIDENT_INFO(<b>'ACCIDENT_NO'</b>,'ACCIDENT_DATE','ACCIDENT_TIME','DAY_WEEK_DESC','POLICE_ATTEND','NO_PERSONS',
# 'NO_OF_VEHICLES','LIGHT_CONDITION','NO_PERSONS_KILLED','NO_PERSONS_INJ_2','NO_PERSONS_INJ_3','NO_PERSONS_NOT_INJ',
# 'SEVERITY', 'SPEED_ZONE', 'RMA','NODE_ID','DCA_CODE')
#
#
# ACCIDENT_LOCATION(<b>'ACCIDENT_NO'</b>,'ROAD_NAME','ROAD_TYPE','ROAD_NAME_INT',
# 'ROAD_TYPE_INT', 'DIRECTION_LOCATION',)
#
# NODE(<b>'ACCIDENT_NO'</b>, 'LGA_NAME', 'DEG_URBAN_NAME', 'LATITUDE', 'LONGITUDE','POSTCODE_CRASH')
#
# ATMOSHPERIC(<b>ACCIDENT_NO,ATMOSPH_COND_SEQ</b>, ATMOSPH_COND)
#
# SUB_DCA(<b>'ACCIDENT_NO', 'SUB_DCA_SEQ'</b>, 'SUB_DCA_CODE', 'SUB_DCA_CODE_DESC')
#
#
# ROAD_SURFACE(<b>'ACCIDENT_NO','SURFACE_COND_SEQ'</b>, 'SURFACE_COND')
#
#
# ACCIDENT_EVENT(<b>'ACCIDENT_NO', 'EVENT_SEQ_NO'</b>, 'EVENT_TYPE','VEHICLE_1_ID', 'VEHICLE_1_COLL_PT', 'VEHICLE 1 COLL PT DESC','VEHICLE_2_ID', 'VEHICLE_2_COLL_PT', 'VEHICLE 2 COLL PT DESC', 'PERSON_ID', 'OBJECT_TYPE')
#
# PERSON(<b>'ACCIDENT_NO','VEHICLE_ID' 'PERSON_ID'</b>, 'SEX', 'AGE_GROUP','INJ_LEVEL', , 'SEATING_POSITION', 'HELMET_BELT_WORN','ROAD_USER_TYPE', 'LICENCE_STATE','TAKEN_HOSPITAL', 'EJECTED_CODE')
#
# VEHICLE(<b>'ACCIDENT_NO', 'VEHICLE_ID'</b>, 'VEHICLE_YEAR_MANUF', 'VEHICLE_DCA_CODE',
#        'INITIAL_DIRECTION', 'ROAD_SURFACE_TYPE', 'ROAD_SURFACE_TYPE_DESC',
#        'REG_STATE', 'VEHICLE_BODY_STYLE', 'VEHICLE_MAKE', 'VEHICLE_MODEL',
#        'VEHICLE_TYPE', 'VEHICLE_TYPE_DESC', 'VEHICLE_WEIGHT', 'FUEL_TYPE',
#        'NO_OF_WHEELS', 'NO_OF_CYLINDERS', 'SEATING_CAPACITY',
#        'TOTAL_NO_OCCUPANTS', 'CARRY_CAPACITY', 'FINAL_DIRECTION',
#        'DRIVER_INTENT', 'VEHICLE_MOVEMENT', 'TRAILER_TYPE', 'VEHICLE_COLOUR_1',
#        'VEHICLE_COLOUR_2', 'CAUGHT_FIRE', 'INITIAL_IMPACT', 'LAMPS',
#        'LEVEL_OF_DAMAGE', 'TOWED_AWAY_FLAG', 'TRAFFIC_CONTROL')
#
#
# ACCIDENT_TYPE(<b>'ACCIDENT_TYPE'</b>,'ACCIDENT_TYPE_DESC',)
#
# DCA_INFO(<b>'DCA_CODE'</b>, 'DCA_DESC',)
#
# ROAD_GEOMETRY(<b>'ROAD_GEOMETRY'</b>, 'ROAD_GEOMETRY_DESC')
#
#
# OBJECT(<b>OBJECT_TYPE</b>, OBJECT_TYPE_DESC)
#
# EVENT_TYPE(<b>EVENT_TYPE</b>, EVENT_TYPE_DESC)
#
# ATMOSPH_COND(<b>ATMOSPH_COND</b>, ATMOSPH_COND_DESC)
#
# ROAD_USER(<b>'ROAD_USER_TYPE'</b>,'ROAD_USER_TYPE_DESC')
#
# INJ_LEVEL(<b>'INJ_LEVEL'</b>,'INJ_LEVEL_DESC')
#
# SURFACE_COND(<b>'SURFACE_COND'</b>, 'SURFACE_COND_DESC')
#
# SUB_DCA_CODE(<b>'SUB_DCA_CODE'</b>, 'SUB_DCA_CODE_DESC')
#
# TRAFFIC_CONTROL(<b>'TRAFFIC_CONTROL'</b>,'TRAFFIC_CONTROL_DESC')
#
# ROAD_SURFACE(<b>ROAD_SURFACE_TYPE</b>, ROAD_SURFACE_TYPE_DESC)

# %%
print(accident_df.shape)
print(accident_location_df.shape)
print(node_df.shape)
# Out:
# (167153, 19)
# (167153, 6)
# (175460, 6)

# %%
167153 + 175460
# Out:
# 342613

# %%
169726
# Out:
# 169726

# %%
accident_df.head()
# Out:
#     ACCIDENT_NO ACCIDENT_DATE ACCIDENT_TIME  ACCIDENT_TYPE DAY_WEEK_DESC  \
# 0  T20120000060    2012-01-01      19:40:00              6        Sunday
# 1  T20120000028    2012-01-01      04:00:00              4        Sunday
# 2  T20120000021    2012-01-01      07:30:00              4        Sunday
# 3  T20120000050    2012-01-01      15:00:00              4        Sunday
# 4  T20120000056    2012-01-01      16:15:00              4        Sunday
#
#    DCA_CODE  LIGHT_CONDITION  NODE_ID  NO_OF_VEHICLES  NO_PERSONS_KILLED  \
# 0       184                1   248602               1                  0
# 1       183                5   248598               1                  0
# 2       171                1   248597               1                  0
# 3       171                1   248600               1                  0
# 4       183                1   249133               1                  0
#
#    NO_PERSONS_INJ_2  NO_PERSONS_INJ_3  NO_PERSONS_NOT_INJ  NO_PERSONS  \
# 0                 1                 0                   0           1
# 1                 1                 0                   0           1
# 2                 0                 2                   1           3
# 3                 0                 1                   0           1
# 4                 2                 0                   0           2
#
#    POLICE_ATTEND  ROAD_GEOMETRY  SEVERITY  SPEED_ZONE         RMA
# 0              1              2         2          60  Local Road
# 1              1              2         2         100  Local Road
# 2              1              5         3          50  Local Road
# 3              1              5         3         999  Local Road
# 4              1              2         2         100  Local Road

# %%
node_df.loc[node_df["ACCIDENT_NO"]=="T20120000060"]
# Out:
#         ACCIDENT_NO LGA_NAME DEG_URBAN_NAME   LATITUDE   LONGITUDE  \
# 64331  T20120000060  WYNDHAM     MELB_URBAN -37.873671  144.739749
#
#       POSTCODE_CRASH
# 64331           3030

# %%
accident_df.loc[accident_df.ACCIDENT_NO.isin(node_df.ACCIDENT_NO).astype(int)==1]
# Out:
#          ACCIDENT_NO ACCIDENT_DATE ACCIDENT_TIME  ACCIDENT_TYPE DAY_WEEK_DESC  \
# 325     T20120001369    2012-01-12      21:00:00              6      Thursday
# 942     T20120002126    2012-01-28      12:00:00              5      Saturday
# 2640    T20120006036    2012-03-08      18:26:00              1      Thursday
# 2690    T20120005932    2012-03-10      14:00:00              8      Saturday
# 3816    T20120008664    2012-04-06      09:50:00              1        Friday
# ...              ...           ...           ...            ...           ...
# 141240  T20220001453    2022-01-20      10:50:00              4      Thursday
# 141833  T20220002483    2022-02-05      17:15:00              1      Saturday
# 144483  T20220007387    2022-04-02      13:52:00              1      Saturday
# 145111  T20220008774    2022-04-18      15:35:00              6        Monday
# 145815  T20220010048    2022-05-04      19:24:00              1     Wednesday
#
#         DCA_CODE  LIGHT_CONDITION  NODE_ID  NO_OF_VEHICLES  NO_PERSONS_KILLED  \
# 325          174                6       -3               1                  0
# 942          166                1      -10               1                  0
# 2640         130                1      -10               2                  0
# 2690         184                1      -10               1                  0
# 3816         132                1      -10               2                  0
# ...          ...              ...      ...             ...                ...
# 141240       173                1       -1               1                  0
# 141833       113                1       -1               2                  0
# 144483       192                1       -1               2                  0
# 145111       180                1       -1               1                  0
# 145815       121                3       -1               2                  0
#
#         NO_PERSONS_INJ_2  NO_PERSONS_INJ_3  NO_PERSONS_NOT_INJ  NO_PERSONS  \
# 325                    0                 1                   0           1
# 942                    1                 0                   0           1
# 2640                   0                 1                   1           2
# 2690                   0                 1                   0           1
# 3816                   1                 0                   2           3
# ...                  ...               ...                 ...         ...
# 141240                 1                 0                   0           1
# 141833                 1                 0                   1           2
# 144483                 0                 1                   2           3
# 145111                 0                 1                   0           1
# 145815                 0                 1                   1           2
#
#         POLICE_ATTEND  ROAD_GEOMETRY  SEVERITY  SPEED_ZONE  RMA
# 325                 2              2         3         999  NaN
# 942                 1              5         2         999  NaN
# 2640                2              5         3          50  NaN
# 2690                2              5         3         100  NaN
# 3816                1              5         2         100  NaN
# ...               ...            ...       ...         ...  ...
# 141240              1              5         2          60  NaN
# 141833              1              2         2          50  NaN
# 144483              1              5         3         888  NaN
# 145111              1              1         3          60  NaN
# 145815              1              1         3          60  NaN
#
# [110 rows x 19 columns]

# %%
accident_df.loc[accident_df["ACCIDENT_NO"]=="T20120000060"]
# Out:
#     ACCIDENT_NO ACCIDENT_DATE ACCIDENT_TIME  ACCIDENT_TYPE DAY_WEEK_DESC  \
# 0  T20120000060    2012-01-01      19:40:00              6        Sunday
#
#    DCA_CODE  LIGHT_CONDITION  NODE_ID  NO_OF_VEHICLES  NO_PERSONS_KILLED  \
# 0       184                1   248602               1                  0
#
#    NO_PERSONS_INJ_2  NO_PERSONS_INJ_3  NO_PERSONS_NOT_INJ  NO_PERSONS  \
# 0                 1                 0                   0           1
#
#    POLICE_ATTEND  ROAD_GEOMETRY  SEVERITY  SPEED_ZONE         RMA
# 0              1              2         2          60  Local Road

# %%
accident_location_df.loc[accident_location_df["ACCIDENT_NO"]=="T20120000060"]
# Out:
#     ACCIDENT_NO ROAD_NAME ROAD_TYPE ROAD_NAME_INT ROAD_TYPE_INT  \
# 0  T20120000060    LINMAX     COURT       WALLACE        AVENUE
#
#   DIRECTION_LOCATION
# 0                 NW

# %%
test = accident_df.merge(accident_location_df)

Accident_Info = test.merge(node_df)

print(Accident_Info.columns)
print(Accident_Info.shape)

Accident_Info
# Out:
# Index(['ACCIDENT_NO', 'ACCIDENT_DATE', 'ACCIDENT_TIME', 'ACCIDENT_TYPE',
#        'DAY_WEEK_DESC', 'DCA_CODE', 'LIGHT_CONDITION', 'NODE_ID',
#        'NO_OF_VEHICLES', 'NO_PERSONS_KILLED', 'NO_PERSONS_INJ_2',
#        'NO_PERSONS_INJ_3', 'NO_PERSONS_NOT_INJ', 'NO_PERSONS', 'POLICE_ATTEND',
#        'ROAD_GEOMETRY', 'SEVERITY', 'SPEED_ZONE', 'RMA', 'ROAD_NAME',
#        'ROAD_TYPE', 'ROAD_NAME_INT', 'ROAD_TYPE_INT', 'DIRECTION_LOCATION',
#        'LGA_NAME', 'DEG_URBAN_NAME', 'LATITUDE', 'LONGITUDE',
#        'POSTCODE_CRASH'],
#       dtype='object')
# (169726, 29)
#          ACCIDENT_NO ACCIDENT_DATE ACCIDENT_TIME  ACCIDENT_TYPE DAY_WEEK_DESC  \
# 0       T20120000060    2012-01-01      19:40:00              6        Sunday
# 1       T20120000028    2012-01-01      04:00:00              4        Sunday
# 2       T20120000021    2012-01-01      07:30:00              4        Sunday
# 3       T20120000050    2012-01-01      15:00:00              4        Sunday
# 4       T20120000056    2012-01-01      16:15:00              4        Sunday
# ...              ...           ...           ...            ...           ...
# 169721  T20230022835    2023-09-30      06:50:00              1      Saturday
# 169722  T20230022889    2023-09-30      23:18:00              4      Saturday
# 169723  T20230022887    2023-09-30      18:55:00              1      Saturday
# 169724  T20230022886    2023-09-30      18:00:00              1      Saturday
# 169725  T20230022860    2023-09-30      12:15:00              1      Saturday
#
#         DCA_CODE  LIGHT_CONDITION  NODE_ID  NO_OF_VEHICLES  NO_PERSONS_KILLED  \
# 0            184                1   248602               1                  0
# 1            183                5   248598               1                  0
# 2            171                1   248597               1                  0
# 3            171                1   248600               1                  0
# 4            183                1   249133               1                  0
# ...          ...              ...      ...             ...                ...
# 169721       130                1    39785               2                  0
# 169722       179                3   797736               1                  0
# 169723       160                3   785255               2                  0
# 169724       160                1   797584               4                  0
# 169725       130                1   350177               2                  0
#
#         ...        ROAD_NAME  ROAD_TYPE  ROAD_NAME_INT  ROAD_TYPE_INT  \
# 0       ...           LINMAX      COURT        WALLACE         AVENUE
# 1       ...            GOBUR       ROAD   MIDDLE CREEK           ROAD
# 2       ...          WILLIAM       ROAD       HARLEIAN         STREET
# 3       ...           GARDEN     STREET        SANWILL         AVENUE
# 4       ...  ANDERSONS INLET       ROAD          JAMES           ROAD
# ...     ...              ...        ...            ...            ...
# 169721  ...           DORSET       ROAD     CANTERBURY           ROAD
# 169722  ...         DRUMMOND     STREET          WELCH          PLACE
# 169723  ...           STUART     STREET        AUGUSTA           ROAD
# 169724  ...          GILBERT       ROAD           VIEW         STREET
# 169725  ...           EDGARS       ROAD       MAHONEYS           ROAD
#
#         DIRECTION_LOCATION              LGA_NAME  DEG_URBAN_NAME   LATITUDE  \
# 0                       NW               WYNDHAM      MELB_URBAN -37.873671
# 1                       NW           MURRINDINDI  RURAL_VICTORIA -37.018449
# 2                       NE  MORNINGTON PENINSULA      MELB_URBAN -38.369561
# 3                        S           WARRNAMBOOL    SMALL_CITIES -38.374190
# 4                        N       SOUTH GIPPSLAND  RURAL_VICTORIA -38.444885
# ...                    ...                   ...             ...        ...
# 169721                   S             MAROONDAH      MELB_URBAN -37.826001
# 169722                   S             MELBOURNE      MELB_URBAN -37.798596
# 169723                  SE                  KNOX      MELB_URBAN -37.858489
# 169724                   S               DAREBIN      MELB_URBAN -37.719912
# 169725                  NE            WHITTLESEA      MELB_URBAN -37.693741
#
#          LONGITUDE POSTCODE_CRASH
# 0       144.739749           3030
# 1       145.643172           3719
# 2       144.777930           3942
# 3       142.502841           3280
# 4       145.747256           3946
# ...            ...            ...
# 169721  145.287586           3153
# 169722  144.968799           3333
# 169723  145.310174           3162
# 169724  144.993155           3902
# 169725  145.000985           3074
#
# [169726 rows x 29 columns]

# %%
print("--------------------")                               
print(Accident_Info.columns)
print("--------------------")
print(Accident_Type.columns)
print("--------------------")
print(DCA_INFO.columns)
print("--------------------")
print(Road_Geometry.columns)
print("--------------------") 
print(accident_event_df.columns)
print("--------------------") 
print(Object_Type.columns)
print("--------------------") 
print(Event_Type.columns)
print("--------------------") 
print(Vehicle_Coll.columns)
print("--------------------") 
print(accident_location_df.columns)
print("--------------------")
print(atmospheric_df.columns)
print("--------------------")
print(ATMOSPH_COND.columns)
print("--------------------")                               
print(node_df.columns)
print("--------------------") 
print(person_df.columns)
print("--------------------") 
print(Inj_Level.columns)
print("--------------------") 
print(Road_User.columns)
print("--------------------") 
print(road_surface_df.columns)
print("--------------------") 
print(Surface_Cond.columns)
print("--------------------") 
print(sub_dca_df.columns)
print("--------------------") 
print(Sub_DCA_Code.columns)
print("--------------------") 
print(vehicle_df.columns)
print("--------------------")
print(Traffic_Control.columns)
print("--------------------")
print(Road_Surface.columns)
# Out:
# --------------------
# Index(['ACCIDENT_NO', 'ACCIDENT_DATE', 'ACCIDENT_TIME', 'ACCIDENT_TYPE',
#        'DAY_WEEK_DESC', 'DCA_CODE', 'LIGHT_CONDITION', 'NODE_ID',
#        'NO_OF_VEHICLES', 'NO_PERSONS_KILLED', 'NO_PERSONS_INJ_2',
#        'NO_PERSONS_INJ_3', 'NO_PERSONS_NOT_INJ', 'NO_PERSONS', 'POLICE_ATTEND',
#        'ROAD_GEOMETRY', 'SEVERITY', 'SPEED_ZONE', 'RMA', 'ROAD_NAME',
#        'ROAD_TYPE', 'ROAD_NAME_INT', 'ROAD_TYPE_INT', 'DIRECTION_LOCATION',
#        'LGA_NAME', 'DEG_URBAN_NAME', 'LATITUDE', 'LONGITUDE',
#        'POSTCODE_CRASH'],
#       dtype='object')
# --------------------
# Index(['ACCIDENT_TYPE', 'ACCIDENT_TYPE_DESC'], dtype='object')
# --------------------
# Index(['DCA_CODE', 'DCA_DESC'], dtype='object')
# --------------------
# Index(['ROAD_GEOMETRY', 'ROAD_GEOMETRY_DESC'], dtype='object')
# --------------------
# Index(['ACCIDENT_NO', 'EVENT_SEQ_NO', 'EVENT_TYPE', 'VEHICLE_1_ID',
#        'VEHICLE_1_COLL_PT', 'VEHICLE 1 COLL PT DESC', 'VEHICLE_2_ID',
#        'VEHICLE_2_COLL_PT', 'VEHICLE 2 COLL PT DESC', 'PERSON_ID',
#        'OBJECT_TYPE'],
#       dtype='object')
# --------------------
# Index(['OBJECT_TYPE', 'OBJECT_TYPE_DESC'], dtype='object')
# --------------------
# Index(['EVENT_TYPE', 'EVENT_TYPE_DESC'], dtype='object')
# --------------------
# Index(['VEHICLE_COLL_PT', 'VEHICLE COLL PT DESC'], dtype='object')
# --------------------
# Index(['ACCIDENT_NO', 'ROAD_NAME', 'ROAD_TYPE', 'ROAD_NAME_INT',
#        'ROAD_TYPE_INT', 'DIRECTION_LOCATION'],
#       dtype='object')
# --------------------
# Index(['ACCIDENT_NO', 'ATMOSPH_COND', 'ATMOSPH_COND_SEQ'], dtype='object')
# --------------------
# Index(['ATMOSPH_COND', 'ATMOSPH_COND_DESC'], dtype='object')
# --------------------
# Index(['ACCIDENT_NO', 'LGA_NAME', 'DEG_URBAN_NAME', 'LATITUDE', 'LONGITUDE',
#        'POSTCODE_CRASH'],
#       dtype='object')
# --------------------
# Index(['ACCIDENT_NO', 'PERSON_ID', 'VEHICLE_ID', 'SEX', 'AGE_GROUP',
#        'INJ_LEVEL', 'INJ_LEVEL_DESC', 'SEATING_POSITION', 'HELMET_BELT_WORN',
#        'ROAD_USER_TYPE', 'ROAD_USER_TYPE_DESC', 'LICENCE_STATE',
#        'TAKEN_HOSPITAL', 'EJECTED_CODE'],
#       dtype='object')
# --------------------
# Index(['INJ_LEVEL', 'INJ_LEVEL_DESC'], dtype='object')
# --------------------
# Index(['ROAD_USER_TYPE', 'ROAD_USER_TYPE_DESC'], dtype='object')
# --------------------
# Index(['ACCIDENT_NO', 'SURFACE_COND', 'SURFACE_COND_SEQ'], dtype='object')
# --------------------
# Index(['SURFACE_COND', 'SURFACE_COND_DESC'], dtype='object')
# --------------------
# Index(['ACCIDENT_NO', 'SUB_DCA_CODE', 'SUB_DCA_SEQ'], dtype='object')
# --------------------
# Index(['SUB_DCA_CODE', 'SUB_DCA_CODE_DESC'], dtype='object')
# --------------------
# Index(['ACCIDENT_NO', 'VEHICLE_ID', 'VEHICLE_YEAR_MANUF', 'VEHICLE_DCA_CODE',
#        'INITIAL_DIRECTION', 'ROAD_SURFACE_TYPE', 'REG_STATE',
#        'VEHICLE_BODY_STYLE', 'VEHICLE_MAKE', 'VEHICLE_MODEL', 'VEHICLE_TYPE',
#        'VEHICLE_TYPE_DESC', 'VEHICLE_WEIGHT', 'FUEL_TYPE', 'NO_OF_WHEELS',
#        'NO_OF_CYLINDERS', 'SEATING_CAPACITY', 'TOTAL_NO_OCCUPANTS',
#        'CARRY_CAPACITY', 'FINAL_DIRECTION', 'DRIVER_INTENT',
#        'VEHICLE_MOVEMENT', 'TRAILER_TYPE', 'VEHICLE_COLOUR_1',
#        'VEHICLE_COLOUR_2', 'CAUGHT_FIRE', 'INITIAL_IMPACT', 'LAMPS',
#        'LEVEL_OF_DAMAGE', 'TOWED_AWAY_FLAG', 'TRAFFIC_CONTROL'],
#       dtype='object')
# --------------------
# Index(['TRAFFIC_CONTROL', 'TRAFFIC_CONTROL_DESC'], dtype='object')
# --------------------
# Index(['ROAD_SURFACE_TYPE', 'ROAD_SURFACE_TYPE_DESC'], dtype='object')

# %% [markdown]
# # All 3NF Forms
#
#
# ACCIDENT_INFO(<b>'ACCIDENT_NO'</b>,'ACCIDENT_DATE','ACCIDENT_TIME','DAY_WEEK_DESC','POLICE_ATTEND','NO_PERSONS',
# 'NO_OF_VEHICLES','LIGHT_CONDITION','NO_PERSONS_KILLED','NO_PERSONS_INJ_2','NO_PERSONS_INJ_3','NO_PERSONS_NOT_INJ',
# 'SEVERITY', 'SPEED_ZONE', 'RMA','NODE_ID','DCA_CODE',ROAD_NAME','ROAD_TYPE','ROAD_NAME_INT',
# 'ROAD_TYPE_INT', 'DIRECTION_LOCATION','LGA_NAME', 'DEG_URBAN_NAME', 'LATITUDE', 'LONGITUDE','POSTCODE_CRASH','SURFACE_COND_SEQ'</b>, 'SURFACE_COND')
#
# ACCIDENT_EVENT(<b>'ACCIDENT_NO', 'EVENT_SEQ_NO'</b>, 'EVENT_TYPE','VEHICLE_1_ID', 'VEHICLE_1_COLL_PT', 'VEHICLE 1 COLL PT DESC','VEHICLE_2_ID', 'VEHICLE_2_COLL_PT', 'VEHICLE 2 COLL PT DESC', 'PERSON_ID', 'OBJECT_TYPE')
#
# SUB_DCA(<b>'ACCIDENT_NO', 'SUB_DCA_SEQ'</b>, 'SUB_DCA_CODE', 'SUB_DCA_CODE_DESC')
# PERSON(<b>'ACCIDENT_NO','VEHICLE_ID' 'PERSON_ID'</b>, 'SEX', 'AGE_GROUP','INJ_LEVEL', , 'SEATING_POSITION', 'HELMET_BELT_WORN','ROAD_USER_TYPE', 'LICENCE_STATE','TAKEN_HOSPITAL', 'EJECTED_CODE')
#
# VEHICLE(<b>'ACCIDENT_NO', 'VEHICLE_ID'</b>, 'VEHICLE_YEAR_MANUF', 'VEHICLE_DCA_CODE',
#        'INITIAL_DIRECTION', 'ROAD_SURFACE_TYPE', 'ROAD_SURFACE_TYPE_DESC',
#        'REG_STATE', 'VEHICLE_BODY_STYLE', 'VEHICLE_MAKE', 'VEHICLE_MODEL',
#        'VEHICLE_TYPE', 'VEHICLE_TYPE_DESC', 'VEHICLE_WEIGHT', 'FUEL_TYPE',
#        'NO_OF_WHEELS', 'NO_OF_CYLINDERS', 'SEATING_CAPACITY',
#        'TOTAL_NO_OCCUPANTS', 'CARRY_CAPACITY', 'FINAL_DIRECTION',
#        'DRIVER_INTENT', 'VEHICLE_MOVEMENT', 'TRAILER_TYPE', 'VEHICLE_COLOUR_1',
#        'VEHICLE_COLOUR_2', 'CAUGHT_FIRE', 'INITIAL_IMPACT', 'LAMPS',
#        'LEVEL_OF_DAMAGE', 'TOWED_AWAY_FLAG', 'TRAFFIC_CONTROL')
#
# ACCIDENT_TYPE(<b>'ACCIDENT_TYPE'</b>,'ACCIDENT_TYPE_DESC',)
#
# DCA_INFO(<b>'DCA_CODE'</b>, 'DCA_DESC',)
#
# ROAD_GEOMETRY(<b>'ROAD_GEOMETRY'</b>, 'ROAD_GEOMETRY_DESC')
#
# OBJECT(<b>OBJECT_TYPE</b>, OBJECT_TYPE_DESC)
#
# EVENT_TYPE(<b>EVENT_TYPE</b>, EVENT_TYPE_DESC)
#
# ATMOSHPERIC(<b>ACCIDENT_NO,ATMOSPH_COND_SEQ</b>, ATMOSPH_COND)
#
# ATMOSPH_COND(<b>ATMOSPH_COND</b>, ATMOSPH_COND_DESC)
#
# ROAD_USER(<b>'ROAD_USER_TYPE'</b>,'ROAD_USER_TYPE_DESC')
#
# INJ_LEVEL(<b>'INJ_LEVEL'</b>,'INJ_LEVEL_DESC')
#
# SURFACE_COND(<b>'SURFACE_COND'</b>, 'SURFACE_COND_DESC')
#
# SUB_DCA_CODE(<b>'SUB_DCA_CODE'</b>, 'SUB_DCA_CODE_DESC')
#
# TRAFFIC_CONTROL(<b>'TRAFFIC_CONTROL'</b>,'TRAFFIC_CONTROL_DESC')
#
# ROAD_SURFACE(<b>ROAD_SURFACE_TYPE</b>, ROAD_SURFACE_TYPE_DESC)
